# %%
import gc
import multiprocessing
from multiprocessing.pool import ThreadPool
import math
import os
import pathlib
import pickle
import random
import time

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import dask
import dask.multiprocessing


from tqdm import tqdm_notebook

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold, train_test_split

import lightgbm as lgb
import xgboost as xgb

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import adam
from keras.callbacks import ModelCheckpoint

# %%
# %matplotlib inline

# %%
dask.config.set(scheduler='processes')
dask.set_options( pool=ThreadPool(10) )
# Out:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/dask/context.py:23: UserWarning: The dask.set_options function has been deprecated. Please use dask.config.set instead
#   warnings.warn("The dask.set_options function has been deprecated. "

# %%
def add_features(
        df,
        input_first_index=None,
        input_last_index=None,
        sample_size=150000,
        holdout_size=50000,
        smootch_windows_size = (3, 5, 7)
    ):
    if input_first_index == None or input_last_index == None:
        input_first_index = df.index.min()
        input_last_index = df.index.max() + 1
        
    
    sample_indexes = random.sample(range(input_first_index, input_last_index), sample_size)
    sample_indexes.sort()
    
    smootch_feature_names = ['smootch_mean_ws_{}'.format(window_size) for window_size in smootch_windows_size]
    acoustic_data_series = df['acoustic_data']
    full_data_indexes = tuple(acoustic_data_series.index.tolist())

    sample_df = df.iloc[sample_indexes]

    sample_df.reset_index(inplace=True)
    sample_df.drop(columns=['index'], inplace=True)

    output_first_index = 0
    output_last_index = len(sample_df) - 1
    
    begin_indexes_set = set()
    end_indexes_set = set()
    
    start_time = time.time()
   
    sample_df_len = sample_df.shape[0]
    for window_size, feature_name in zip(smootch_windows_size, smootch_feature_names):

        feature_values_list = list(range(sample_size))

        half_window_size = window_size // 2

        sample_begin_indexes = sample_indexes[:half_window_size]
        full_data_begin_indexes = set(df.index[sample_begin_indexes].tolist())
        min_full_data_index = min(full_data_indexes)
        
        in_window_full_data_begin_indexes = set(range(input_first_index, input_first_index + half_window_size))              
        in_window_begin_indexes = full_data_begin_indexes.intersection(
            in_window_full_data_begin_indexes
        )
        
        sample_end_indexes = sample_indexes[-half_window_size:]
        full_data_end_indexes = set(df.index[sample_end_indexes].tolist())
        max_full_data_index = max(full_data_end_indexes) + 1
        
        in_window_full_data_end_indexes = set(range(input_last_index - half_window_size, input_last_index))        
        in_window_end_indexes = full_data_end_indexes.intersection(
            in_window_full_data_end_indexes
        )
        if in_window_begin_indexes:
            begin_indexes_set = begin_indexes_set.union(in_window_begin_indexes)
            for i, b_idx in enumerate(sorted(tuple(in_window_begin_indexes))):
                value = sample_df.iloc[i]['acoustic_data']
                temp = acoustic_data_series.iloc[input_first_index:input_first_index + window_size].mean()
                value = value - temp
                feature_values_list[output_first_index + i] = value
                
        if in_window_end_indexes:
            end_indexes_set = end_indexes_set.union(in_window_end_indexes)
            for i, e_idx in enumerate(sorted(tuple(in_window_end_indexes))):
                value = sample_df.iloc[output_last_index - i]['acoustic_data']
                temp = acoustic_data_series.iloc[input_last_index - window_size:].mean()
                value = value - temp
                feature_values_list[output_last_index - i] = value
                
        first_regular_idx = len(begin_indexes_set)
        last_regular_idx = sample_df_len - len(end_indexes_set)
        for i in range(first_regular_idx, last_regular_idx):
            sample_idx = sample_indexes[i]
            feature_values_list[i] = acoustic_data_series.iloc[
                sample_idx - half_window_size:sample_idx + half_window_size
            ].mean()
        sample_df[feature_name] = feature_values_list
        
    holdout_df = None
    if holdout_size > 0:
        holdout_indexes = np.random.randint(0, sample_df.shape[0], holdout_size)
        holdout_df = sample_df.iloc[holdout_indexes]
        holdout_df.reset_index(inplace=True)
        holdout_df.drop(columns=['index'], inplace=True)
        train_indexes = sorted(tuple(set(sample_df.index).difference(set(holdout_indexes))))
        sample_df = sample_df.iloc[train_indexes]
        sample_df.reset_index(inplace=True)
        sample_df.drop(columns=['index'], inplace=True)
    print("Full calculation feature value time (with slicing) {} min:".format((time.time() - start_time) / 60))
    return sample_df, holdout_df

# %%
def add_features_dask_parralel(
#def add_features_parallel(
        df,
        input_first_index=None,
        input_last_index=None,
        sample_size=150000,
        holdout_size=50000,
        smootch_windows_size = (3, 5, 7)
    ):
    if input_first_index == None or input_last_index == None:
        input_first_index = df.index.min()
        input_last_index = df.index.max() + 1
        
    
    sample_indexes = random.sample(range(input_first_index, input_last_index), sample_size)
    sample_indexes.sort()
    
    smootch_feature_names = ['smootch_mean_ws_{}'.format(window_size) for window_size in smootch_windows_size]
    acoustic_data_series = df['acoustic_data']
    full_data_indexes = tuple(acoustic_data_series.index.tolist())

    sample_df = df.iloc[sample_indexes]

    sample_df.reset_index(inplace=True)
    sample_df.drop(columns=['index'], inplace=True)

    output_first_index = 0
    output_last_index = len(sample_df) - 1
    
    begin_indexes_set = set()
    end_indexes_set = set()
    
    start_time = time.time()
   
    sample_df_len = sample_df.shape[0]
    @dask.delayed
    def create_features():
        for window_size, feature_name in zip(smootch_windows_size, smootch_feature_names):

            feature_values_list = list(range(sample_size))

            half_window_size = window_size // 2

            sample_begin_indexes = sample_indexes[:half_window_size]
            full_data_begin_indexes = set(df.index[sample_begin_indexes].tolist())
            min_full_data_index = min(full_data_indexes)
        
            in_window_full_data_begin_indexes = set(range(input_first_index, input_first_index + half_window_size))              
            in_window_begin_indexes = full_data_begin_indexes.intersection(
                in_window_full_data_begin_indexes
            )
        
            sample_end_indexes = sample_indexes[-half_window_size:]
            full_data_end_indexes = set(df.index[sample_end_indexes].tolist())
            max_full_data_index = max(full_data_end_indexes) + 1
        
            in_window_full_data_end_indexes = set(range(input_last_index - half_window_size, input_last_index))        
            in_window_end_indexes = full_data_end_indexes.intersection(
                in_window_full_data_end_indexes
            )
            if in_window_begin_indexes:
                begin_indexes_set = begin_indexes_set.union(in_window_begin_indexes)
                for i, b_idx in enumerate(sorted(tuple(in_window_begin_indexes))):
                    value = sample_df.iloc[i]['acoustic_data']
                    temp = acoustic_data_series.iloc[input_first_index:input_first_index + window_size].mean()
                    value = value - temp
                    feature_values_list[output_first_index + i] = value
                
            if in_window_end_indexes:
                end_indexes_set = end_indexes_set.union(in_window_end_indexes)
                for i, e_idx in enumerate(sorted(tuple(in_window_end_indexes))):
                    value = sample_df.iloc[output_last_index - i]['acoustic_data']
                    temp = acoustic_data_series.iloc[input_last_index - window_size:].mean()
                    value = value - temp
                    feature_values_list[output_last_index - i] = value
                
            first_regular_idx = len(begin_indexes_set)
            last_regular_idx = sample_df_len - len(end_indexes_set)
            for i in range(first_regular_idx, last_regular_idx):
                sample_idx = sample_indexes[i]
                feature_values_list[i] = acoustic_data_series.iloc[
                    sample_idx - half_window_size:sample_idx + half_window_size
                ].mean()
            sample_df[feature_name] = feature_values_list
        return sample_df
        
    holdout_df = None
    if holdout_size > 0:
        holdout_indexes = np.random.randint(0, sample_df.shape[0], holdout_size)
        holdout_df = sample_df.iloc[holdout_indexes]
        holdout_df.reset_index(inplace=True)
        holdout_df.drop(columns=['index'], inplace=True)
        train_indexes = sorted(tuple(set(sample_df.index).difference(set(holdout_indexes))))
        sample_df = sample_df.iloc[train_indexes]
        sample_df.reset_index(inplace=True)
        sample_df.drop(columns=['index'], inplace=True)
    print("Full calculation feature value time (with slicing) {} min:".format((time.time() - start_time) / 60))
    return sample_df, holdout_df

# %%
add_features = add_features_dask_parralel

# %%
earthquake_margin_indexes =[
    5656573,
    50085877,
    104677355,
    138772452,
    187641819,
    218652629,
    245829584,
    307838916,
    338276286,
    375377847,
    419368879,
    461811622,
    495800224,
    528777114,
    585568143,
    621985672
]

# %%
earthquakes_length = [earthquake_margin_indexes[i + 1] - earthquake_margin_indexes[i] for i in range(len(earthquake_margin_indexes) - 1)]

# %%
earthquakes_length
# Out:
# [44429304,
#  54591478,
#  34095097,
#  48869367,
#  31010810,
#  27176955,
#  62009332,
#  30437370,
#  37101561,
#  43991032,
#  42442743,
#  33988602,
#  32976890,
#  56791029,
#  36417529]

# %%
complete_earthquakes_length = earthquakes_length[:-1]

# %%
#complete_earthquaces_length = complete_earthquaces_length[:-1]

# %%
complete_earthquakes_length
# Out:
# [44429304,
#  54591478,
#  34095097,
#  48869367,
#  31010810,
#  27176955,
#  62009332,
#  30437370,
#  37101561,
#  43991032,
#  42442743,
#  33988602,
#  32976890,
#  56791029]

# %%
params = {
    #'num_leaves': 51,
    'num_leaves': 27,
    #'min_data_in_leaf': 10,
    'min_data_in_leaf': 8,
    'objective':'regression',
    #'max_depth': -1,
    'max_depth': 5,
    'learning_rate': 0.001,
    'boosting': 'gbdt',
    #'feature_fraction': 0.91,
    #'bagging_freq': 1,
    #'bagging_fraction': 0.91,
    #'bagging_seed': 42,
    'metric': 'mae',
    #'lambda_l1': 0.1,
    'verbosity': -1,
    'nthread': 10,
    'random_state': 42
}

# %%
def train_models(
        earthquake_margin_indexes,
        complete_earthquakes_length,
        params,
        featured_not_seen_data_df,
        sample_size=None,
        holdout_size=None,
        #not_seen_data_begin=1,
        #not_seen_data_end=5656572 #5656569
    ):
    
    '''
    not_seen_data_df = pd.read_csv(
        '../input/train/train.csv',
        #nrows=100000000,
        names=['acoustic_data', 'time_to_failure'],
        dtype={'acoustic_data': np.float32, 'time_to_failure': np.float32},
        skiprows=not_seen_data_begin,
        nrows=not_seen_data_end
    )
    
    not_seen_data_df, _ = add_features(
        not_seen_data_df,
        sample_size=not_seen_data_df.shape[0],
        holdout_size=0
    )
    '''
    y_not_seen_data = featured_not_seen_data_df['time_to_failure']
    featured_not_seen_data_df = featured_not_seen_data_df[featured_not_seen_data_df.columns.drop('time_to_failure')]
    
    for i in range(len(complete_earthquakes_length)):
        print("i:", i)
        print("complete_earthquakes_length:", complete_earthquakes_length[i])
        print("earthquake_margin_indexes:", earthquake_margin_indexes[i])
        
        earthquake_df = pd.read_csv(
                '../input/train/train.csv',
                #nrows=100000000,
                names=['acoustic_data', 'time_to_failure'],
                dtype={'acoustic_data': np.float32, 'time_to_failure': np.float32},
                skiprows=earthquake_margin_indexes[i],
                nrows=complete_earthquakes_length[i]
            )
        if not sample_size:
            sample_size = complete_earthquakes_length[i] // 10
        if not holdout_size:
            holdout_size = complete_earthquakes_length[i] // 50
        earthquake_add_features_df, holdout_add_features_df = add_features(
                earthquake_df,
                sample_size=sample_size,
                holdout_size=holdout_size
            )
        X_all = earthquake_add_features_df[earthquake_add_features_df.columns.drop('time_to_failure')]
        y_all = earthquake_add_features_df['time_to_failure']

        X_train, X_valid, y_train, y_valid = train_test_split(X_all, y_all, test_size=0.2, random_state=0)

        model = lgb.LGBMRegressor(**params, n_estimators = 20000, n_jobs = 10, num_iterations=40000)
        model.fit(
                X_train,
                y_train,
                eval_set=[(X_train, y_train), (X_valid, y_valid)],
                eval_metric='mae',
                verbose=1000,
                early_stopping_rounds=4000
            )
        X_holdout = holdout_add_features_df[holdout_add_features_df.columns.drop('time_to_failure')]
        y_holdout = holdout_add_features_df['time_to_failure']
        
        y_holdout_predict = model.predict(X_holdout)
        print("earthquake {} mae {}".format(i, mean_absolute_error(y_holdout, y_holdout_predict)))
        
        not_seen_data_predict = model.predict(featured_not_seen_data_df)
        print("not seen data mae: {}".format(mean_absolute_error(y_not_seen_data, not_seen_data_predict)))
        not_seen_data_predict_df = pd.DataFrame({'time_to_failure': not_seen_data_predict})
        not_seen_data_predict_df.to_csv('not_seend_data_earthquake_{}_model_predict.csv'.format(i), index=False)

        #model.save_model('earthquake_{}_model.txt'.format(i))
        #model.Booster(model_file='earthquake_{}_model.txt'.format(i))
        model_file = open('earthquake_{}_model.txt'.format(i), 'wb')
        pickle.dump(model, model_file)
        model_file.flush()
        model_file.close()

    return

# %%
# %%time
not_seen_data_df = pd.read_csv(
    '../input/train/train.csv',
    #nrows=100000000,
    names=['acoustic_data', 'time_to_failure'],
    dtype={'acoustic_data': np.float32, 'time_to_failure': np.float32},
    skiprows=1,
    nrows=5656572
)
# Out:
# CPU times: user 1.38 s, sys: 80 ms, total: 1.46 s
# Wall time: 1.46 s

# %%
# %%time
featured_not_seen_data_df, _ = add_features(
    not_seen_data_df,
    sample_size=not_seen_data_df.shape[0] // 20,
    holdout_size=0
)
# Out:
# Full calculation feature value time (with slicing) 5.046526590983073e-06 min:
# CPU times: user 984 ms, sys: 212 ms, total: 1.2 s
# Wall time: 1.19 s

# %%
# %%time
train_models(earthquake_margin_indexes, complete_earthquakes_length, params, featured_not_seen_data_df)
# Out:
# i: 0
# complete_earthquakes_length: 44429304
# earthquake_margin_indexes: 5656573
# Full calculation feature value time (with slicing) 0.04236885706583659 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 2.86507	valid_1's l1: 2.86328
# [2000]	training's l1: 2.86135	valid_1's l1: 2.85949
# [3000]	training's l1: 2.8605	valid_1's l1: 2.8586
# [4000]	training's l1: 2.86026	valid_1's l1: 2.85834
# [5000]	training's l1: 2.86017	valid_1's l1: 2.85825
# [6000]	training's l1: 2.86014	valid_1's l1: 2.85822
# [7000]	training's l1: 2.86012	valid_1's l1: 2.85821
# [8000]	training's l1: 2.86012	valid_1's l1: 2.85821
# [9000]	training's l1: 2.86012	valid_1's l1: 2.85821
# [10000]	training's l1: 2.86012	valid_1's l1: 2.85821
# [11000]	training's l1: 2.86011	valid_1's l1: 2.85821
# [12000]	training's l1: 2.86011	valid_1's l1: 2.85821
# [13000]	training's l1: 2.86011	valid_1's l1: 2.85821
# [14000]	training's l1: 2.86011	valid_1's l1: 2.85821
# [15000]	training's l1: 2.86011	valid_1's l1: 2.85821
# [16000]	training's l1: 2.86011	valid_1's l1: 2.85821
# Early stopping, best iteration is:
# [12350]	training's l1: 2.86011	valid_1's l1: 2.85821
# earthquake 0 mae 2.861247320949805
# not seen data mae: 5.003631563163498
# i: 1
# complete_earthquakes_length: 54591478
# earthquake_margin_indexes: 50085877
# Full calculation feature value time (with slicing) 0.04329955577850342 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 3.51704	valid_1's l1: 3.51685
# [2000]	training's l1: 3.51158	valid_1's l1: 3.51121
# [3000]	training's l1: 3.51015	valid_1's l1: 3.50971
# [4000]	training's l1: 3.5097	valid_1's l1: 3.50923
# [5000]	training's l1: 3.50954	valid_1's l1: 3.50906
# [6000]	training's l1: 3.50948	valid_1's l1: 3.50901
# [7000]	training's l1: 3.50946	valid_1's l1: 3.50899
# [8000]	training's l1: 3.50945	valid_1's l1: 3.50899
# [9000]	training's l1: 3.50945	valid_1's l1: 3.50899
# [10000]	training's l1: 3.50945	valid_1's l1: 3.50899
# [11000]	training's l1: 3.50944	valid_1's l1: 3.50899
# [12000]	training's l1: 3.50944	valid_1's l1: 3.50899
# Early stopping, best iteration is:
# [8255]	training's l1: 3.50945	valid_1's l1: 3.50899
# earthquake 1 mae 3.5114871244390997
# not seen data mae: 6.334338894587381
# i: 2
# complete_earthquakes_length: 34095097
# earthquake_margin_indexes: 104677355
# Full calculation feature value time (with slicing) 0.04176505009333293 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 2.18953	valid_1's l1: 2.18646
# [2000]	training's l1: 2.18368	valid_1's l1: 2.18059
# [3000]	training's l1: 2.182	valid_1's l1: 2.17888
# [4000]	training's l1: 2.18145	valid_1's l1: 2.17833
# [5000]	training's l1: 2.18125	valid_1's l1: 2.17814
# [6000]	training's l1: 2.18118	valid_1's l1: 2.17807
# [7000]	training's l1: 2.18115	valid_1's l1: 2.17805
# [8000]	training's l1: 2.18114	valid_1's l1: 2.17804
# [9000]	training's l1: 2.18114	valid_1's l1: 2.17804
# [10000]	training's l1: 2.18113	valid_1's l1: 2.17804
# [11000]	training's l1: 2.18113	valid_1's l1: 2.17804
# [12000]	training's l1: 2.18113	valid_1's l1: 2.17804
# [13000]	training's l1: 2.18113	valid_1's l1: 2.17804
# [14000]	training's l1: 2.18113	valid_1's l1: 2.17804
# Early stopping, best iteration is:
# [10764]	training's l1: 2.18113	valid_1's l1: 2.17804
# earthquake 2 mae 2.1822420931093793
# not seen data mae: 3.6585048869825108
# i: 3
# complete_earthquakes_length: 48869367
# earthquake_margin_indexes: 138772452
# Full calculation feature value time (with slicing) 0.04335764646530151 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 3.14204	valid_1's l1: 3.13913
# [2000]	training's l1: 3.13488	valid_1's l1: 3.13186
# [3000]	training's l1: 3.1329	valid_1's l1: 3.12985
# [4000]	training's l1: 3.13226	valid_1's l1: 3.1292
# [5000]	training's l1: 3.13203	valid_1's l1: 3.12897
# [6000]	training's l1: 3.13195	valid_1's l1: 3.12889
# [7000]	training's l1: 3.13192	valid_1's l1: 3.12886
# [8000]	training's l1: 3.13191	valid_1's l1: 3.12886
# [9000]	training's l1: 3.1319	valid_1's l1: 3.12886
# [10000]	training's l1: 3.1319	valid_1's l1: 3.12886
# [11000]	training's l1: 3.13189	valid_1's l1: 3.12886
# Early stopping, best iteration is:
# [7941]	training's l1: 3.13191	valid_1's l1: 3.12886
# earthquake 3 mae 3.129220831194849
# not seen data mae: 5.583504634929253
# i: 4
# complete_earthquakes_length: 31010810
# earthquake_margin_indexes: 187641819
# Full calculation feature value time (with slicing) 0.042831977208455406 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 1.99592	valid_1's l1: 1.99622
# [2000]	training's l1: 1.99165	valid_1's l1: 1.99196
# [3000]	training's l1: 1.99043	valid_1's l1: 1.99075
# [4000]	training's l1: 1.99003	valid_1's l1: 1.99036
# [5000]	training's l1: 1.98988	valid_1's l1: 1.99022
# [6000]	training's l1: 1.98983	valid_1's l1: 1.99017
# [7000]	training's l1: 1.98981	valid_1's l1: 1.99015
# [8000]	training's l1: 1.9898	valid_1's l1: 1.99015
# [9000]	training's l1: 1.98979	valid_1's l1: 1.99014
# [10000]	training's l1: 1.98979	valid_1's l1: 1.99014
# [11000]	training's l1: 1.98979	valid_1's l1: 1.99014
# [12000]	training's l1: 1.98978	valid_1's l1: 1.99014
# [13000]	training's l1: 1.98978	valid_1's l1: 1.99014
# [14000]	training's l1: 1.98978	valid_1's l1: 1.99014
# [15000]	training's l1: 1.98978	valid_1's l1: 1.99014
# [16000]	training's l1: 1.98978	valid_1's l1: 1.99014
# [17000]	training's l1: 1.98978	valid_1's l1: 1.99014
# [18000]	training's l1: 1.98978	valid_1's l1: 1.99014
# [19000]	training's l1: 1.98978	valid_1's l1: 1.99014
# [20000]	training's l1: 1.98978	valid_1's l1: 1.99014
# [21000]	training's l1: 1.98978	valid_1's l1: 1.99014
# [22000]	training's l1: 1.98978	valid_1's l1: 1.99014
# [23000]	training's l1: 1.98978	valid_1's l1: 1.99014
# [24000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [25000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [26000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [27000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [28000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [29000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [30000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [31000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [32000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [33000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [34000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [35000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [36000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [37000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [38000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [39000]	training's l1: 1.98977	valid_1's l1: 1.99014
# [40000]	training's l1: 1.98977	valid_1's l1: 1.99014
# Did not meet early stopping. Best iteration is:
# [40000]	training's l1: 1.98977	valid_1's l1: 1.99014
# earthquake 4 mae 1.9905344571285915
# not seen data mae: 3.2515918414178824
# i: 5
# complete_earthquakes_length: 27176955
# earthquake_margin_indexes: 218652629
# Full calculation feature value time (with slicing) 0.04190343221028646 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 1.75285	valid_1's l1: 1.75206
# [2000]	training's l1: 1.74966	valid_1's l1: 1.74895
# [3000]	training's l1: 1.74871	valid_1's l1: 1.74801
# [4000]	training's l1: 1.74839	valid_1's l1: 1.7477
# [5000]	training's l1: 1.74827	valid_1's l1: 1.74759
# [6000]	training's l1: 1.74823	valid_1's l1: 1.74755
# [7000]	training's l1: 1.74822	valid_1's l1: 1.74754
# [8000]	training's l1: 1.74821	valid_1's l1: 1.74754
# [9000]	training's l1: 1.74821	valid_1's l1: 1.74754
# [10000]	training's l1: 1.7482	valid_1's l1: 1.74753
# [11000]	training's l1: 1.7482	valid_1's l1: 1.74753
# [12000]	training's l1: 1.7482	valid_1's l1: 1.74753
# [13000]	training's l1: 1.7482	valid_1's l1: 1.74753
# [14000]	training's l1: 1.7482	valid_1's l1: 1.74753
# [15000]	training's l1: 1.7482	valid_1's l1: 1.74753
# [16000]	training's l1: 1.7482	valid_1's l1: 1.74753
# [17000]	training's l1: 1.7482	valid_1's l1: 1.74753
# [18000]	training's l1: 1.7482	valid_1's l1: 1.74753
# [19000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [20000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [21000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [22000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [23000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [24000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [25000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [26000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [27000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [28000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [29000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [30000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [31000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [32000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [33000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [34000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [35000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [36000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [37000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [38000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [39000]	training's l1: 1.74819	valid_1's l1: 1.74753
# [40000]	training's l1: 1.74819	valid_1's l1: 1.74753
# Did not meet early stopping. Best iteration is:
# [40000]	training's l1: 1.74819	valid_1's l1: 1.74753
# earthquake 5 mae 1.7462150443985733
# not seen data mae: 2.7731650740149205
# i: 6
# complete_earthquakes_length: 62009332
# earthquake_margin_indexes: 245829584
# Full calculation feature value time (with slicing) 0.042617146174112955 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 4.00153	valid_1's l1: 3.99877
# [2000]	training's l1: 3.99531	valid_1's l1: 3.99254
# [3000]	training's l1: 3.99358	valid_1's l1: 3.99083
# [4000]	training's l1: 3.99302	valid_1's l1: 3.99028
# [5000]	training's l1: 3.99282	valid_1's l1: 3.99009
# [6000]	training's l1: 3.99275	valid_1's l1: 3.99002
# [7000]	training's l1: 3.99272	valid_1's l1: 3.99
# [8000]	training's l1: 3.99271	valid_1's l1: 3.98999
# [9000]	training's l1: 3.9927	valid_1's l1: 3.98999
# [10000]	training's l1: 3.9927	valid_1's l1: 3.98999
# [11000]	training's l1: 3.99269	valid_1's l1: 3.98999
# [12000]	training's l1: 3.99269	valid_1's l1: 3.98999
# Early stopping, best iteration is:
# [8441]	training's l1: 3.9927	valid_1's l1: 3.98999
# earthquake 6 mae 3.9908463494983475
# not seen data mae: 7.2921466053095925
# i: 7
# complete_earthquakes_length: 30437370
# earthquake_margin_indexes: 307838916
# Full calculation feature value time (with slicing) 0.042690805594126385 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 1.95717	valid_1's l1: 1.95655
# [2000]	training's l1: 1.95251	valid_1's l1: 1.95184
# [3000]	training's l1: 1.95115	valid_1's l1: 1.95047
# [4000]	training's l1: 1.9507	valid_1's l1: 1.95002
# [5000]	training's l1: 1.95054	valid_1's l1: 1.94986
# [6000]	training's l1: 1.95048	valid_1's l1: 1.9498
# [7000]	training's l1: 1.95046	valid_1's l1: 1.94979
# [8000]	training's l1: 1.95045	valid_1's l1: 1.94978
# [9000]	training's l1: 1.95045	valid_1's l1: 1.94978
# [10000]	training's l1: 1.95044	valid_1's l1: 1.94978
# [11000]	training's l1: 1.95044	valid_1's l1: 1.94978
# [12000]	training's l1: 1.95044	valid_1's l1: 1.94978
# [13000]	training's l1: 1.95044	valid_1's l1: 1.94977
# [14000]	training's l1: 1.95044	valid_1's l1: 1.94977
# [15000]	training's l1: 1.95043	valid_1's l1: 1.94977
# [16000]	training's l1: 1.95043	valid_1's l1: 1.94977
# [17000]	training's l1: 1.95043	valid_1's l1: 1.94977
# [18000]	training's l1: 1.95043	valid_1's l1: 1.94977
# [19000]	training's l1: 1.95043	valid_1's l1: 1.94977
# [20000]	training's l1: 1.95043	valid_1's l1: 1.94977
# [21000]	training's l1: 1.95043	valid_1's l1: 1.94977
# [22000]	training's l1: 1.95043	valid_1's l1: 1.94977
# [23000]	training's l1: 1.95043	valid_1's l1: 1.94977
# [24000]	training's l1: 1.95043	valid_1's l1: 1.94977
# Early stopping, best iteration is:
# [20477]	training's l1: 1.95043	valid_1's l1: 1.94977
# earthquake 7 mae 1.9492257469626508
# not seen data mae: 3.171644049197151
# i: 8
# complete_earthquakes_length: 37101561
# earthquake_margin_indexes: 338276286
# Full calculation feature value time (with slicing) 0.04248218933741252 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 2.38657	valid_1's l1: 2.38638
# [2000]	training's l1: 2.38128	valid_1's l1: 2.38132
# [3000]	training's l1: 2.37977	valid_1's l1: 2.37989
# [4000]	training's l1: 2.37926	valid_1's l1: 2.37941
# [5000]	training's l1: 2.37908	valid_1's l1: 2.37925
# [6000]	training's l1: 2.37901	valid_1's l1: 2.37919
# [7000]	training's l1: 2.37899	valid_1's l1: 2.37918
# [8000]	training's l1: 2.37898	valid_1's l1: 2.37917
# [9000]	training's l1: 2.37898	valid_1's l1: 2.37917
# [10000]	training's l1: 2.37897	valid_1's l1: 2.37917
# [11000]	training's l1: 2.37897	valid_1's l1: 2.37917
# [12000]	training's l1: 2.37897	valid_1's l1: 2.37917
# [13000]	training's l1: 2.37897	valid_1's l1: 2.37917
# [14000]	training's l1: 2.37896	valid_1's l1: 2.37917
# [15000]	training's l1: 2.37896	valid_1's l1: 2.37917
# [16000]	training's l1: 2.37896	valid_1's l1: 2.37917
# Early stopping, best iteration is:
# [12844]	training's l1: 2.37897	valid_1's l1: 2.37917
# earthquake 8 mae 2.377870049730631
# not seen data mae: 4.048532323517733
# i: 9
# complete_earthquakes_length: 43991032
# earthquake_margin_indexes: 375377847
# Full calculation feature value time (with slicing) 0.0406834602355957 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 2.83503	valid_1's l1: 2.83279
# [2000]	training's l1: 2.82954	valid_1's l1: 2.82728
# [3000]	training's l1: 2.82798	valid_1's l1: 2.8257
# [4000]	training's l1: 2.82746	valid_1's l1: 2.82518
# [5000]	training's l1: 2.82728	valid_1's l1: 2.825
# [6000]	training's l1: 2.82721	valid_1's l1: 2.82493
# [7000]	training's l1: 2.82718	valid_1's l1: 2.82492
# [8000]	training's l1: 2.82717	valid_1's l1: 2.82492
# [9000]	training's l1: 2.82716	valid_1's l1: 2.82492
# [10000]	training's l1: 2.82716	valid_1's l1: 2.82492
# [11000]	training's l1: 2.82715	valid_1's l1: 2.82492
# [12000]	training's l1: 2.82715	valid_1's l1: 2.82492
# [13000]	training's l1: 2.82715	valid_1's l1: 2.82492
# [14000]	training's l1: 2.82714	valid_1's l1: 2.82492
# [15000]	training's l1: 2.82714	valid_1's l1: 2.82492
# Early stopping, best iteration is:
# [11797]	training's l1: 2.82715	valid_1's l1: 2.82492
# earthquake 9 mae 2.82520527008766
# not seen data mae: 4.946327380800211
# i: 10
# complete_earthquakes_length: 42442743
# earthquake_margin_indexes: 419368879
# Full calculation feature value time (with slicing) 0.042436762650807695 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 2.73172	valid_1's l1: 2.72878
# [2000]	training's l1: 2.7259	valid_1's l1: 2.72288
# [3000]	training's l1: 2.72423	valid_1's l1: 2.7212
# [4000]	training's l1: 2.72368	valid_1's l1: 2.72065
# [5000]	training's l1: 2.72349	valid_1's l1: 2.72046
# [6000]	training's l1: 2.72342	valid_1's l1: 2.72039
# [7000]	training's l1: 2.72339	valid_1's l1: 2.72037
# [8000]	training's l1: 2.72338	valid_1's l1: 2.72037
# [9000]	training's l1: 2.72337	valid_1's l1: 2.72036
# [10000]	training's l1: 2.72336	valid_1's l1: 2.72036
# [11000]	training's l1: 2.72336	valid_1's l1: 2.72036
# [12000]	training's l1: 2.72336	valid_1's l1: 2.72036
# [13000]	training's l1: 2.72335	valid_1's l1: 2.72036
# [14000]	training's l1: 2.72335	valid_1's l1: 2.72036
# [15000]	training's l1: 2.72335	valid_1's l1: 2.72036
# [16000]	training's l1: 2.72335	valid_1's l1: 2.72036
# [17000]	training's l1: 2.72335	valid_1's l1: 2.72036
# [18000]	training's l1: 2.72335	valid_1's l1: 2.72036
# Early stopping, best iteration is:
# [14221]	training's l1: 2.72335	valid_1's l1: 2.72036
# earthquake 10 mae 2.721441050379709
# not seen data mae: 4.747109725053335
# i: 11
# complete_earthquakes_length: 33988602
# earthquake_margin_indexes: 461811622
# Full calculation feature value time (with slicing) 0.0405925194422404 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 2.18322	valid_1's l1: 2.18001
# [2000]	training's l1: 2.17746	valid_1's l1: 2.17415
# [3000]	training's l1: 2.1758	valid_1's l1: 2.17246
# [4000]	training's l1: 2.17525	valid_1's l1: 2.17191
# [5000]	training's l1: 2.17506	valid_1's l1: 2.17171
# [6000]	training's l1: 2.17499	valid_1's l1: 2.17164
# [7000]	training's l1: 2.17496	valid_1's l1: 2.17162
# [8000]	training's l1: 2.17495	valid_1's l1: 2.17161
# [9000]	training's l1: 2.17495	valid_1's l1: 2.17161
# [10000]	training's l1: 2.17494	valid_1's l1: 2.17161
# [11000]	training's l1: 2.17494	valid_1's l1: 2.17161
# [12000]	training's l1: 2.17494	valid_1's l1: 2.17161
# [13000]	training's l1: 2.17494	valid_1's l1: 2.17161
# [14000]	training's l1: 2.17494	valid_1's l1: 2.17161
# [15000]	training's l1: 2.17494	valid_1's l1: 2.17161
# [16000]	training's l1: 2.17494	valid_1's l1: 2.17161
# [17000]	training's l1: 2.17494	valid_1's l1: 2.17161
# Early stopping, best iteration is:
# [13403]	training's l1: 2.17494	valid_1's l1: 2.17161
# earthquake 11 mae 2.1744266674076083
# not seen data mae: 3.63959719513833
# i: 12
# complete_earthquakes_length: 32976890
# earthquake_margin_indexes: 495800224
# Full calculation feature value time (with slicing) 0.04216781457265218 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 2.12266	valid_1's l1: 2.12067
# [2000]	training's l1: 2.1182	valid_1's l1: 2.1162
# [3000]	training's l1: 2.11691	valid_1's l1: 2.1149
# [4000]	training's l1: 2.11648	valid_1's l1: 2.11446
# [5000]	training's l1: 2.11633	valid_1's l1: 2.11431
# [6000]	training's l1: 2.11627	valid_1's l1: 2.11425
# [7000]	training's l1: 2.11625	valid_1's l1: 2.11423
# [8000]	training's l1: 2.11624	valid_1's l1: 2.11423
# [9000]	training's l1: 2.11624	valid_1's l1: 2.11423
# [10000]	training's l1: 2.11624	valid_1's l1: 2.11423
# [11000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [12000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [13000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [14000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [15000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [16000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [17000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [18000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [19000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [20000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [21000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [22000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [23000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [24000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [25000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [26000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [27000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [28000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [29000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [30000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [31000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [32000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [33000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [34000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [35000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [36000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [37000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [38000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [39000]	training's l1: 2.11623	valid_1's l1: 2.11422
# [40000]	training's l1: 2.11623	valid_1's l1: 2.11422
# Did not meet early stopping. Best iteration is:
# [40000]	training's l1: 2.11623	valid_1's l1: 2.11422
# earthquake 12 mae 2.1173360694802073
# not seen data mae: 3.5069134379173863
# i: 13
# complete_earthquakes_length: 56791029
# earthquake_margin_indexes: 528777114
# Full calculation feature value time (with slicing) 0.04150435527165731 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 3.66196	valid_1's l1: 3.65794
# [2000]	training's l1: 3.65669	valid_1's l1: 3.6526
# [3000]	training's l1: 3.65527	valid_1's l1: 3.65117
# [4000]	training's l1: 3.65482	valid_1's l1: 3.65072
# [5000]	training's l1: 3.65466	valid_1's l1: 3.65056
# [6000]	training's l1: 3.6546	valid_1's l1: 3.65051
# [7000]	training's l1: 3.65458	valid_1's l1: 3.6505
# [8000]	training's l1: 3.65457	valid_1's l1: 3.6505
# [9000]	training's l1: 3.65456	valid_1's l1: 3.65049
# [10000]	training's l1: 3.65456	valid_1's l1: 3.65049
# [11000]	training's l1: 3.65455	valid_1's l1: 3.65049
# [12000]	training's l1: 3.65455	valid_1's l1: 3.6505
# [13000]	training's l1: 3.65454	valid_1's l1: 3.6505
# Early stopping, best iteration is:
# [9253]	training's l1: 3.65456	valid_1's l1: 3.65049
# earthquake 13 mae 3.6547771288815145
# not seen data mae: 6.627150714360123
# CPU times: user 1d 7h 30min 35s, sys: 3min 25s, total: 1d 7h 34min 1s
# Wall time: 3h 50min 33s

# %%
# %%time
train_models(earthquake_margin_indexes[:5], complete_earthquakes_length, params, featured_not_seen_data_df)
# Out:
# i: 0
# complete_earthquakes_length: 44429304
# earthquake_margin_indexes: 5656573
# Full calculation feature value time (with slicing) 49.81775324344635 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 2.85065	valid_1's l1: 2.84681
# [2000]	training's l1: 2.84416	valid_1's l1: 2.84038
# [3000]	training's l1: 2.84234	valid_1's l1: 2.83866
# [4000]	training's l1: 2.84161	valid_1's l1: 2.83803
# [5000]	training's l1: 2.84124	valid_1's l1: 2.83775
# [6000]	training's l1: 2.84104	valid_1's l1: 2.83763
# [7000]	training's l1: 2.8409	valid_1's l1: 2.83756
# [8000]	training's l1: 2.84078	valid_1's l1: 2.83749
# [9000]	training's l1: 2.84067	valid_1's l1: 2.83744
# [10000]	training's l1: 2.84057	valid_1's l1: 2.83741
# [11000]	training's l1: 2.84048	valid_1's l1: 2.83738
# [12000]	training's l1: 2.84039	valid_1's l1: 2.83735
# [13000]	training's l1: 2.84031	valid_1's l1: 2.83733
# [14000]	training's l1: 2.84023	valid_1's l1: 2.83731
# [15000]	training's l1: 2.84015	valid_1's l1: 2.83729
# [16000]	training's l1: 2.84008	valid_1's l1: 2.83728
# [17000]	training's l1: 2.84002	valid_1's l1: 2.83726
# [18000]	training's l1: 2.83995	valid_1's l1: 2.83725
# [19000]	training's l1: 2.83988	valid_1's l1: 2.83724
# [20000]	training's l1: 2.83982	valid_1's l1: 2.83723
# [21000]	training's l1: 2.83975	valid_1's l1: 2.83722
# [22000]	training's l1: 2.83969	valid_1's l1: 2.83721
# [23000]	training's l1: 2.83963	valid_1's l1: 2.83721
# [24000]	training's l1: 2.83957	valid_1's l1: 2.8372
# [25000]	training's l1: 2.83951	valid_1's l1: 2.8372
# [26000]	training's l1: 2.83945	valid_1's l1: 2.83719
# [27000]	training's l1: 2.83939	valid_1's l1: 2.83719
# [28000]	training's l1: 2.83933	valid_1's l1: 2.83718
# [29000]	training's l1: 2.83927	valid_1's l1: 2.83718
# [30000]	training's l1: 2.83922	valid_1's l1: 2.83718
# [31000]	training's l1: 2.83917	valid_1's l1: 2.83718
# [32000]	training's l1: 2.83912	valid_1's l1: 2.83718
# [33000]	training's l1: 2.83906	valid_1's l1: 2.83718
# [34000]	training's l1: 2.83902	valid_1's l1: 2.83717
# [35000]	training's l1: 2.83897	valid_1's l1: 2.83717
# [36000]	training's l1: 2.83892	valid_1's l1: 2.83717
# [37000]	training's l1: 2.83886	valid_1's l1: 2.83717
# [38000]	training's l1: 2.83882	valid_1's l1: 2.83718
# [39000]	training's l1: 2.83877	valid_1's l1: 2.83718
# Early stopping, best iteration is:
# [35572]	training's l1: 2.83894	valid_1's l1: 2.83717
# earthquake 0 mae 2.8426040633192877
# not seen data mae: 4.9757274988665126
# i: 1
# complete_earthquakes_length: 54591478
# earthquake_margin_indexes: 50085877
# Full calculation feature value time (with slicing) 49.020149918397266 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 3.49634	valid_1's l1: 3.4937
# [2000]	training's l1: 3.48612	valid_1's l1: 3.48335
# [3000]	training's l1: 3.48298	valid_1's l1: 3.48026
# [4000]	training's l1: 3.48165	valid_1's l1: 3.47903
# [5000]	training's l1: 3.48099	valid_1's l1: 3.47847
# [6000]	training's l1: 3.48067	valid_1's l1: 3.47824
# [7000]	training's l1: 3.48048	valid_1's l1: 3.47812
# [8000]	training's l1: 3.48032	valid_1's l1: 3.47804
# [9000]	training's l1: 3.48017	valid_1's l1: 3.47797
# [10000]	training's l1: 3.48003	valid_1's l1: 3.47791
# [11000]	training's l1: 3.47989	valid_1's l1: 3.47786
# [12000]	training's l1: 3.47978	valid_1's l1: 3.47783
# [13000]	training's l1: 3.47967	valid_1's l1: 3.4778
# [14000]	training's l1: 3.47956	valid_1's l1: 3.47777
# [15000]	training's l1: 3.47946	valid_1's l1: 3.47774
# [16000]	training's l1: 3.47936	valid_1's l1: 3.47771
# [17000]	training's l1: 3.47926	valid_1's l1: 3.4777
# [18000]	training's l1: 3.47917	valid_1's l1: 3.47769
# [19000]	training's l1: 3.47909	valid_1's l1: 3.47769
# [20000]	training's l1: 3.479	valid_1's l1: 3.47767
# [21000]	training's l1: 3.47891	valid_1's l1: 3.47767
# [22000]	training's l1: 3.47883	valid_1's l1: 3.47765
# [23000]	training's l1: 3.47874	valid_1's l1: 3.47764
# [24000]	training's l1: 3.47865	valid_1's l1: 3.47764
# [25000]	training's l1: 3.47857	valid_1's l1: 3.47764
# [26000]	training's l1: 3.4785	valid_1's l1: 3.47763
# [27000]	training's l1: 3.47842	valid_1's l1: 3.47763
# [28000]	training's l1: 3.47834	valid_1's l1: 3.47763
# [29000]	training's l1: 3.47826	valid_1's l1: 3.47763
# [30000]	training's l1: 3.47818	valid_1's l1: 3.47763
# [31000]	training's l1: 3.47811	valid_1's l1: 3.47763
# [32000]	training's l1: 3.47804	valid_1's l1: 3.47762
# [33000]	training's l1: 3.47797	valid_1's l1: 3.47761
# [34000]	training's l1: 3.4779	valid_1's l1: 3.47761
# [35000]	training's l1: 3.47783	valid_1's l1: 3.4776
# [36000]	training's l1: 3.47775	valid_1's l1: 3.4776
# [37000]	training's l1: 3.47769	valid_1's l1: 3.47761
# [38000]	training's l1: 3.47763	valid_1's l1: 3.47761
# [39000]	training's l1: 3.47756	valid_1's l1: 3.47762
# Early stopping, best iteration is:
# [35764]	training's l1: 3.47777	valid_1's l1: 3.4776
# earthquake 1 mae 3.479469701948243
# not seen data mae: 6.325065739566783
# i: 2
# complete_earthquakes_length: 34095097
# earthquake_margin_indexes: 104677355
# Full calculation feature value time (with slicing) 48.97959547837575 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 2.17361	valid_1's l1: 2.17271
# [2000]	training's l1: 2.16396	valid_1's l1: 2.1632
# [3000]	training's l1: 2.16088	valid_1's l1: 2.16024
# [4000]	training's l1: 2.15964	valid_1's l1: 2.15911
# [5000]	training's l1: 2.15905	valid_1's l1: 2.15862
# [6000]	training's l1: 2.15875	valid_1's l1: 2.15838
# [7000]	training's l1: 2.15859	valid_1's l1: 2.15827
# [8000]	training's l1: 2.15846	valid_1's l1: 2.1582
# [9000]	training's l1: 2.15836	valid_1's l1: 2.15814
# [10000]	training's l1: 2.15827	valid_1's l1: 2.1581
# [11000]	training's l1: 2.15819	valid_1's l1: 2.15806
# [12000]	training's l1: 2.15811	valid_1's l1: 2.15804
# [13000]	training's l1: 2.15805	valid_1's l1: 2.15801
# [14000]	training's l1: 2.15798	valid_1's l1: 2.15799
# [15000]	training's l1: 2.15792	valid_1's l1: 2.15798
# [16000]	training's l1: 2.15786	valid_1's l1: 2.15797
# [17000]	training's l1: 2.15781	valid_1's l1: 2.15796
# [18000]	training's l1: 2.15775	valid_1's l1: 2.15794
# [19000]	training's l1: 2.1577	valid_1's l1: 2.15793
# [20000]	training's l1: 2.15765	valid_1's l1: 2.15792
# [21000]	training's l1: 2.15759	valid_1's l1: 2.15791
# [22000]	training's l1: 2.15754	valid_1's l1: 2.1579
# [23000]	training's l1: 2.1575	valid_1's l1: 2.1579
# [24000]	training's l1: 2.15745	valid_1's l1: 2.1579
# [25000]	training's l1: 2.1574	valid_1's l1: 2.15789
# [26000]	training's l1: 2.15736	valid_1's l1: 2.15789
# [27000]	training's l1: 2.1573	valid_1's l1: 2.15788
# [28000]	training's l1: 2.15726	valid_1's l1: 2.15788
# [29000]	training's l1: 2.15721	valid_1's l1: 2.15788
# [30000]	training's l1: 2.15717	valid_1's l1: 2.15788
# [31000]	training's l1: 2.15713	valid_1's l1: 2.15788
# [32000]	training's l1: 2.15709	valid_1's l1: 2.15788
# Early stopping, best iteration is:
# [28102]	training's l1: 2.15725	valid_1's l1: 2.15788
# earthquake 2 mae 2.160020576845308
# not seen data mae: 3.6335698329067743
# i: 3
# complete_earthquakes_length: 48869367
# earthquake_margin_indexes: 138772452
# Full calculation feature value time (with slicing) 49.1321715315183 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 3.11877	valid_1's l1: 3.11816
# [2000]	training's l1: 3.10619	valid_1's l1: 3.10578
# [3000]	training's l1: 3.10225	valid_1's l1: 3.10198
# [4000]	training's l1: 3.10064	valid_1's l1: 3.10049
# [5000]	training's l1: 3.0999	valid_1's l1: 3.09983
# [6000]	training's l1: 3.09955	valid_1's l1: 3.09955
# [7000]	training's l1: 3.0993	valid_1's l1: 3.09937
# [8000]	training's l1: 3.09911	valid_1's l1: 3.09923
# [9000]	training's l1: 3.09894	valid_1's l1: 3.09911
# [10000]	training's l1: 3.09879	valid_1's l1: 3.09902
# [11000]	training's l1: 3.09865	valid_1's l1: 3.09894
# [12000]	training's l1: 3.09853	valid_1's l1: 3.09888
# [13000]	training's l1: 3.09842	valid_1's l1: 3.09882
# [14000]	training's l1: 3.09832	valid_1's l1: 3.09878
# [15000]	training's l1: 3.09822	valid_1's l1: 3.09874
# [16000]	training's l1: 3.09813	valid_1's l1: 3.0987
# [17000]	training's l1: 3.09804	valid_1's l1: 3.09867
# [18000]	training's l1: 3.09795	valid_1's l1: 3.09864
# [19000]	training's l1: 3.09787	valid_1's l1: 3.09862
# [20000]	training's l1: 3.09778	valid_1's l1: 3.0986
# [21000]	training's l1: 3.0977	valid_1's l1: 3.09858
# [22000]	training's l1: 3.09761	valid_1's l1: 3.09856
# [23000]	training's l1: 3.09754	valid_1's l1: 3.09855
# [24000]	training's l1: 3.09746	valid_1's l1: 3.09853
# [25000]	training's l1: 3.09738	valid_1's l1: 3.09852
# [26000]	training's l1: 3.09732	valid_1's l1: 3.09851
# [27000]	training's l1: 3.09725	valid_1's l1: 3.09849
# [28000]	training's l1: 3.09718	valid_1's l1: 3.09848
# [29000]	training's l1: 3.09711	valid_1's l1: 3.09847
# [30000]	training's l1: 3.09704	valid_1's l1: 3.09846
# [31000]	training's l1: 3.09697	valid_1's l1: 3.09845
# [32000]	training's l1: 3.09691	valid_1's l1: 3.09844
# [33000]	training's l1: 3.09684	valid_1's l1: 3.09844
# [34000]	training's l1: 3.09678	valid_1's l1: 3.09843
# [35000]	training's l1: 3.09672	valid_1's l1: 3.09843
# [36000]	training's l1: 3.09666	valid_1's l1: 3.09842
# [37000]	training's l1: 3.0966	valid_1's l1: 3.09842
# [38000]	training's l1: 3.09655	valid_1's l1: 3.09841
# [39000]	training's l1: 3.09649	valid_1's l1: 3.09841
# [40000]	training's l1: 3.09643	valid_1's l1: 3.09841
# Did not meet early stopping. Best iteration is:
# [40000]	training's l1: 3.09643	valid_1's l1: 3.09841
# earthquake 3 mae 3.1004043556534837
# not seen data mae: 5.55652905613795
# i: 4
# complete_earthquakes_length: 31010810
# earthquake_margin_indexes: 187641819
# Full calculation feature value time (with slicing) 48.606642369429274 min:
# /home/uldo/miniconda3/envs/DS-New/lib/python3.6/site-packages/lightgbm/engine.py:102: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 4000 rounds.
# [1000]	training's l1: 1.9837	valid_1's l1: 1.98141
# [2000]	training's l1: 1.97651	valid_1's l1: 1.9744
# [3000]	training's l1: 1.97429	valid_1's l1: 1.97228
# [4000]	training's l1: 1.97342	valid_1's l1: 1.97148
# [5000]	training's l1: 1.97302	valid_1's l1: 1.97114
# [6000]	training's l1: 1.97284	valid_1's l1: 1.971
# [7000]	training's l1: 1.97272	valid_1's l1: 1.97092
# [8000]	training's l1: 1.97263	valid_1's l1: 1.97088
# [9000]	training's l1: 1.97255	valid_1's l1: 1.97085
# [10000]	training's l1: 1.97248	valid_1's l1: 1.97082
# [11000]	training's l1: 1.97241	valid_1's l1: 1.9708
# [12000]	training's l1: 1.97234	valid_1's l1: 1.97077
# [13000]	training's l1: 1.97227	valid_1's l1: 1.97075
# [14000]	training's l1: 1.97221	valid_1's l1: 1.97074
# [15000]	training's l1: 1.97215	valid_1's l1: 1.97072
# [16000]	training's l1: 1.9721	valid_1's l1: 1.97072
# [17000]	training's l1: 1.97205	valid_1's l1: 1.97071
# [18000]	training's l1: 1.97201	valid_1's l1: 1.97071
# [19000]	training's l1: 1.97196	valid_1's l1: 1.9707
# [20000]	training's l1: 1.97192	valid_1's l1: 1.97069
# [21000]	training's l1: 1.97188	valid_1's l1: 1.97069
# [22000]	training's l1: 1.97183	valid_1's l1: 1.97069
# [23000]	training's l1: 1.97178	valid_1's l1: 1.97068
# [24000]	training's l1: 1.97174	valid_1's l1: 1.97068
# [25000]	training's l1: 1.97169	valid_1's l1: 1.97067
# [26000]	training's l1: 1.97165	valid_1's l1: 1.97067
# [27000]	training's l1: 1.97161	valid_1's l1: 1.97066
# [28000]	training's l1: 1.97157	valid_1's l1: 1.97066
# [29000]	training's l1: 1.97153	valid_1's l1: 1.97066
# [30000]	training's l1: 1.97149	valid_1's l1: 1.97066
# [31000]	training's l1: 1.97146	valid_1's l1: 1.97066
# [32000]	training's l1: 1.97142	valid_1's l1: 1.97066
# Early stopping, best iteration is:
# [28299]	training's l1: 1.97156	valid_1's l1: 1.97066
# earthquake 4 mae 1.9713747282201317
# not seen data mae: 3.219866358448397
# i: 5
# complete_earthquakes_length: 27176955
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <timed eval> in <module>()
#
# <ipython-input-23-61f244112eb8> in train_models(earthquake_margin_indexes, complete_earthquakes_length, params, featured_not_seen_data_df, sample_size, holdout_size)
#      32         print("i:", i)
#      33         print("complete_earthquakes_length:", complete_earthquakes_length[i])
# ---> 34         print("earthquake_margin_indexes:", earthquake_margin_indexes[i])
#      35
#      36         earthquake_df = pd.read_csv(
#
# IndexError: list index out of range

# %%
y_not_seen_data = featured_not_seen_data_df['time_to_failure']
featured_not_seen_data_no_time_df = featured_not_seen_data_df[featured_not_seen_data_df.columns.drop('time_to_failure')]

# %%
for i in range(5, 15):
    model_file = open('earthquake_{}_model.txt'.format(i), 'rb')
    model = pickle.load(model_file)
    model_file.close()
    not_seen_data_predict = model.predict(featured_not_seen_data_no_time_df)
    print("not seen data mae: {}".format(mean_absolute_error(y_not_seen_data, not_seen_data_predict)))
    not_seen_data_predict_df = pd.DataFrame({'time_to_failure': not_seen_data_predict})
    not_seen_data_predict_df.to_csv('not_seend_data_earthquake_{}_model_predict.csv'.format(i), index=False)
# Out:
# not seen data mae: 2.762850373105831
# not seen data mae: 7.260232979477146
# not seen data mae: 3.1379145540556395
# not seen data mae: 4.024417336485413
# not seen data mae: 4.9262122734709335
# not seen data mae: 4.927543366133553
# not seen data mae: 4.725996147452754
# not seen data mae: 3.610067084837362
# not seen data mae: 3.4795987507724666
# not seen data mae: 6.62556275849406

# %%
#featured_not_seen_data_df.drop?

# %%
predictions_df = pd.DataFrame()
for i in (2, 3, 5, 7, 12, 13):
    earthquake_pred_df  = pd.read_csv('not_seend_data_earthquake_{}_model_predict.csv'.format(i))
    predictions_df['pred {}'.format(i)] = earthquake_pred_df['time_to_failure']

# %%
compound_prediction = pd.DataFrame()
compound_prediction['time_to_failure'] = predictions_df.mean(axis=1)

# %%
mean_absolute_error(y_not_seen_data, compound_prediction.values)
# Out:
# 3.696729091456896

# %%
all_predictions_df = pd.DataFrame()
for i in range(15):
    earthquake_pred_df  = pd.read_csv('not_seend_data_earthquake_{}_model_predict.csv'.format(i))
    all_predictions_df['pred {}'.format(i)] = earthquake_pred_df['time_to_failure']

# %%
compound_all_prediction = pd.DataFrame()
compound_all_prediction['time_to_failure'] = all_predictions_df.mean(axis=1)

# %%
mean_absolute_error(y_not_seen_data, compound_all_prediction.values)
# Out:
# 4.612704339503629

# %%
gc.collect()
# Out:
# 528

# %%
# !ls ../input/test/
# Out:
# seg_00030f.csv	seg_335170.csv	seg_6c309f.csv	seg_9d7490.csv	seg_cecd29.csv
# seg_0012b5.csv	seg_337b8c.csv	seg_6c34c2.csv	seg_9d79d4.csv	seg_ced992.csv
# seg_00184e.csv	seg_339f80.csv	seg_6c8a45.csv	seg_9dcae1.csv	seg_cedf3e.csv
# seg_003339.csv	seg_33c30d.csv	seg_6c909f.csv	seg_9ddc99.csv	seg_cee7d0.csv
# seg_0042cc.csv	seg_342ce6.csv	seg_6cfb76.csv	seg_9dea8d.csv	seg_cf0e43.csv
# seg_004314.csv	seg_343571.csv	seg_6d01a3.csv	seg_9df32d.csv	seg_cf1371.csv
# seg_004cd2.csv	seg_3452b2.csv	seg_6d35cd.csv	seg_9e25e9.csv	seg_cf25d2.csv
# seg_004ee5.csv	seg_34a2b8.csv	seg_6d36a1.csv	seg_9e3837.csv	seg_cf3825.csv
# seg_004f1f.csv	seg_34a8f7.csv	seg_6d4109.csv	seg_9e61da.csv	seg_cf5764.csv
# seg_00648a.csv	seg_34abd2.csv	seg_6d4fa6.csv	seg_9e7dff.csv	seg_cf646e.csv
# seg_006e4a.csv	seg_34ef79.csv	seg_6d6fad.csv	seg_9e8323.csv	seg_cf74e8.csv
# seg_007a37.csv	seg_3506d6.csv	seg_6da1ff.csv	seg_9e8ca4.csv	seg_cf9a49.csv
# seg_00a37e.csv	seg_35269b.csv	seg_6dac5d.csv	seg_9e962b.csv	seg_cfed24.csv
# seg_00be11.csv	seg_355717.csv	seg_6dd0fc.csv	seg_9ee0aa.csv	seg_cff594.csv
# seg_00c35b.csv	seg_355d19.csv	seg_6de4fd.csv	seg_9f042e.csv	seg_d014a3.csv
# seg_00cc91.csv	seg_35a2d7.csv	seg_6de935.csv	seg_9f12c6.csv	seg_d0598e.csv
# seg_00e5f7.csv	seg_35b009.csv	seg_6df48e.csv	seg_9f22a0.csv	seg_d062a6.csv
# seg_00f3b9.csv	seg_35b753.csv	seg_6dfab7.csv	seg_9f4fd4.csv	seg_d07c62.csv
# seg_010eab.csv	seg_35ba8f.csv	seg_6e12ae.csv	seg_9f57c4.csv	seg_d07ce8.csv
# seg_0125d9.csv	seg_35c587.csv	seg_6e12ee.csv	seg_9f6315.csv	seg_d098df.csv
# seg_0144cb.csv	seg_35dd45.csv	seg_6e1ee7.csv	seg_9f7542.csv	seg_d0c280.csv
# seg_0165c6.csv	seg_35ee83.csv	seg_6e572a.csv	seg_9fc7c2.csv	seg_d0c8e2.csv
# seg_016913.csv	seg_36147d.csv	seg_6e5a38.csv	seg_9fd9b8.csv	seg_d0f262.csv
# seg_016cdb.csv	seg_361f5a.csv	seg_6e7f73.csv	seg_9fe8b9.csv	seg_d0f803.csv
# seg_017314.csv	seg_3631ec.csv	seg_6e98aa.csv	seg_a00985.csv	seg_d1045e.csv
# seg_01a8dc.csv	seg_3661de.csv	seg_6eb146.csv	seg_a009e6.csv	seg_d11ca8.csv
# seg_01c775.csv	seg_369570.csv	seg_6ed49a.csv	seg_a03e6a.csv	seg_d14524.csv
# seg_01ecb0.csv	seg_36b77f.csv	seg_6edcb8.csv	seg_a05c22.csv	seg_d146a6.csv
# seg_02042f.csv	seg_36e32d.csv	seg_6eedcc.csv	seg_a06228.csv	seg_d16534.csv
# seg_025e78.csv	seg_3706be.csv	seg_6f17de.csv	seg_a0646a.csv	seg_d19980.csv
# seg_032822.csv	seg_373a04.csv	seg_6f2222.csv	seg_a0979e.csv	seg_d1a281.csv
# seg_0339ca.csv	seg_373ba6.csv	seg_6f3d90.csv	seg_a0a423.csv	seg_d1a2b9.csv
# seg_037461.csv	seg_37608b.csv	seg_6f60b2.csv	seg_a11dd5.csv	seg_d1a8b3.csv
# seg_038879.csv	seg_3761d0.csv	seg_6f650f.csv	seg_a12acb.csv	seg_d1abaa.csv
# seg_03d386.csv	seg_37669c.csv	seg_6f9a98.csv	seg_a133bc.csv	seg_d1b91e.csv
# seg_03d63e.csv	seg_376908.csv	seg_6fb17f.csv	seg_a14212.csv	seg_d1ca05.csv
# seg_03d680.csv	seg_377134.csv	seg_6fc3ef.csv	seg_a16a1b.csv	seg_d1cb37.csv
# seg_03f380.csv	seg_3788c5.csv	seg_6fc8b3.csv	seg_a173d8.csv	seg_d1eee8.csv
# seg_0445d7.csv	seg_37bf85.csv	seg_6fd5bb.csv	seg_a18246.csv	seg_d1fbb8.csv
# seg_046c28.csv	seg_37f3fb.csv	seg_7012af.csv	seg_a1a511.csv	seg_d21066.csv
# seg_0488a1.csv	seg_38001b.csv	seg_7020c5.csv	seg_a1acb2.csv	seg_d21eb6.csv
# seg_049957.csv	seg_383b6b.csv	seg_702e03.csv	seg_a1b3cc.csv	seg_d24095.csv
# seg_04a696.csv	seg_383f2e.csv	seg_703cea.csv	seg_a1d8da.csv	seg_d247da.csv
# seg_04ae38.csv	seg_3865bc.csv	seg_705463.csv	seg_a1e5b0.csv	seg_d2551a.csv
# seg_04b87a.csv	seg_3878d0.csv	seg_708349.csv	seg_a1edc1.csv	seg_d26f7d.csv
# seg_04cceb.csv	seg_389906.csv	seg_70991d.csv	seg_a247ac.csv	seg_d27193.csv
# seg_04ee93.csv	seg_38ad16.csv	seg_709b6a.csv	seg_a25c46.csv	seg_d27812.csv
# seg_04fd93.csv	seg_38ee24.csv	seg_709d08.csv	seg_a2986f.csv	seg_d29a4b.csv
# seg_0536c9.csv	seg_392019.csv	seg_70a60e.csv	seg_a2c108.csv	seg_d2a533.csv
# seg_055127.csv	seg_39300d.csv	seg_70b375.csv	seg_a2d47d.csv	seg_d2ad9a.csv
# seg_05a1b0.csv	seg_395e0e.csv	seg_70be4d.csv	seg_a2e2c8.csv	seg_d2cb02.csv
# seg_05a4ad.csv	seg_397983.csv	seg_70e891.csv	seg_a2fd8b.csv	seg_d2db6b.csv
# seg_05b66a.csv	seg_397dc9.csv	seg_70edf5.csv	seg_a31d6e.csv	seg_d2f588.csv
# seg_05bef4.csv	seg_398a25.csv	seg_70fb30.csv	seg_a31fe3.csv	seg_d30a9d.csv
# seg_05e0d7.csv	seg_39a886.csv	seg_7120ac.csv	seg_a35c82.csv	seg_d31583.csv
# seg_05f126.csv	seg_39ad50.csv	seg_71238c.csv	seg_a35e7c.csv	seg_d320f5.csv
# seg_05f9d6.csv	seg_3a1600.csv	seg_71348a.csv	seg_a39ebc.csv	seg_d328bb.csv
# seg_060ce4.csv	seg_3a22ac.csv	seg_715e2c.csv	seg_a39f3b.csv	seg_d32f71.csv
# seg_061a33.csv	seg_3a80c5.csv	seg_715ff6.csv	seg_a39fa8.csv	seg_d32f8a.csv
# seg_0620e6.csv	seg_3a8a76.csv	seg_7189ca.csv	seg_a3ab46.csv	seg_d35274.csv
# seg_063865.csv	seg_3aca44.csv	seg_718b53.csv	seg_a3d4d6.csv	seg_d356ab.csv
# seg_065588.csv	seg_3adb1a.csv	seg_71936f.csv	seg_a41c2c.csv	seg_d35e50.csv
# seg_06893f.csv	seg_3ae4d9.csv	seg_71b4e0.csv	seg_a4208a.csv	seg_d36055.csv
# seg_06b8c9.csv	seg_3af649.csv	seg_71b975.csv	seg_a420d4.csv	seg_d36342.csv
# seg_06bbc5.csv	seg_3b2013.csv	seg_71c9e9.csv	seg_a436bc.csv	seg_d36681.csv
# seg_06d4a2.csv	seg_3b30fd.csv	seg_71f571.csv	seg_a437cb.csv	seg_d36737.csv
# seg_06d7ba.csv	seg_3b4414.csv	seg_7211f1.csv	seg_a45455.csv	seg_d37b05.csv
# seg_070bb0.csv	seg_3b7175.csv	seg_724df9.csv	seg_a47cce.csv	seg_d39131.csv
# seg_071067.csv	seg_3b7724.csv	seg_725772.csv	seg_a489e1.csv	seg_d398df.csv
# seg_073696.csv	seg_3b95d2.csv	seg_725e84.csv	seg_a49ccc.csv	seg_d3992e.csv
# seg_075340.csv	seg_3b95dc.csv	seg_727fc7.csv	seg_a4ad7c.csv	seg_d3bb14.csv
# seg_075f77.csv	seg_3ba485.csv	seg_72858d.csv	seg_a4e745.csv	seg_d3d8fc.csv
# seg_0775a7.csv	seg_3bb90a.csv	seg_72859b.csv	seg_a50d28.csv	seg_d3f6b0.csv
# seg_077b7e.csv	seg_3bc9ed.csv	seg_72aba8.csv	seg_a5271e.csv	seg_d3f967.csv
# seg_079e34.csv	seg_3bd97e.csv	seg_72b68c.csv	seg_a53e4c.csv	seg_d40bb2.csv
# seg_07c815.csv	seg_3bf9ac.csv	seg_72c307.csv	seg_a543e5.csv	seg_d41daa.csv
# seg_07cd72.csv	seg_3bfcf6.csv	seg_72ebda.csv	seg_a55540.csv	seg_d42c77.csv
# seg_07f37c.csv	seg_3c3ddf.csv	seg_72f40a.csv	seg_a55a17.csv	seg_d44589.csv
# seg_07f8df.csv	seg_3c4106.csv	seg_730ebe.csv	seg_a56c04.csv	seg_d47aba.csv
# seg_07fc6d.csv	seg_3c64fb.csv	seg_734a88.csv	seg_a58a6e.csv	seg_d4c763.csv
# seg_086a61.csv	seg_3c8545.csv	seg_73565e.csv	seg_a5934a.csv	seg_d4dec8.csv
# seg_0870ab.csv	seg_3cba49.csv	seg_735cdd.csv	seg_a5d37f.csv	seg_d4ea17.csv
# seg_0879a8.csv	seg_3cbccf.csv	seg_73858d.csv	seg_a5dea6.csv	seg_d508db.csv
# seg_08b136.csv	seg_3ce740.csv	seg_738be6.csv	seg_a5f4dd.csv	seg_d516e3.csv
# seg_08f441.csv	seg_3cfb73.csv	seg_739643.csv	seg_a5fbcc.csv	seg_d56ae2.csv
# seg_08fd5b.csv	seg_3d059a.csv	seg_739679.csv	seg_a61e1c.csv	seg_d56d32.csv
# seg_091c9d.csv	seg_3d06cc.csv	seg_739856.csv	seg_a63573.csv	seg_d59e4e.csv
# seg_093a0a.csv	seg_3d19fc.csv	seg_739fb0.csv	seg_a674d2.csv	seg_d5b100.csv
# seg_0968f1.csv	seg_3d1cb3.csv	seg_73ab4a.csv	seg_a68007.csv	seg_d5d3a1.csv
# seg_0981f3.csv	seg_3d1f2e.csv	seg_73b0f7.csv	seg_a68ffb.csv	seg_d5dbc1.csv
# seg_09dd59.csv	seg_3d581c.csv	seg_740837.csv	seg_a69246.csv	seg_d5df41.csv
# seg_09ed4e.csv	seg_3d6aac.csv	seg_741fc1.csv	seg_a6959c.csv	seg_d5f344.csv
# seg_09f0ff.csv	seg_3d6e79.csv	seg_74235f.csv	seg_a6bf91.csv	seg_d60d18.csv
# seg_0a0fbb.csv	seg_3d9aa0.csv	seg_7428e7.csv	seg_a6c5cc.csv	seg_d62e9c.csv
# seg_0a1bd0.csv	seg_3db0a8.csv	seg_743775.csv	seg_a6cd86.csv	seg_d63175.csv
# seg_0a42ba.csv	seg_3e00cd.csv	seg_74537f.csv	seg_a6e801.csv	seg_d661ce.csv
# seg_0a45a1.csv	seg_3e55d5.csv	seg_746d1d.csv	seg_a6e99c.csv	seg_d668c0.csv
# seg_0a97c4.csv	seg_3e87b4.csv	seg_7480f4.csv	seg_a6eed3.csv	seg_d68930.csv
# seg_0aa0fb.csv	seg_3ec967.csv	seg_74b264.csv	seg_a704ee.csv	seg_d693b0.csv
# seg_0b07c7.csv	seg_3edf51.csv	seg_74b3bd.csv	seg_a7561c.csv	seg_d6b198.csv
# seg_0b082e.csv	seg_3f2086.csv	seg_74ce61.csv	seg_a7b454.csv	seg_d6b386.csv
# seg_0b32f7.csv	seg_3f3689.csv	seg_74d58a.csv	seg_a7d0eb.csv	seg_d6b546.csv
# seg_0b3b94.csv	seg_3f3983.csv	seg_74d8cc.csv	seg_a7e49b.csv	seg_d6dad6.csv
# seg_0b48c4.csv	seg_3f5be6.csv	seg_74dda9.csv	seg_a80123.csv	seg_d6ea73.csv
# seg_0b4b24.csv	seg_3f80ef.csv	seg_74f330.csv	seg_a802fa.csv	seg_d702b2.csv
# seg_0b54ac.csv	seg_3f99c8.csv	seg_74fcfc.csv	seg_a80f6f.csv	seg_d71352.csv
# seg_0b76f5.csv	seg_3fb24b.csv	seg_74ffde.csv	seg_a82229.csv	seg_d740b2.csv
# seg_0b9ad8.csv	seg_3fc7ca.csv	seg_750244.csv	seg_a84c13.csv	seg_d753f8.csv
# seg_0b9ba3.csv	seg_3fdae0.csv	seg_750c93.csv	seg_a86231.csv	seg_d78093.csv
# seg_0ba210.csv	seg_407b2b.csv	seg_750d20.csv	seg_a8685e.csv	seg_d78e7d.csv
# seg_0ba585.csv	seg_40b3aa.csv	seg_750e7e.csv	seg_a86a05.csv	seg_d795ab.csv
# seg_0bb5fd.csv	seg_40f810.csv	seg_75211e.csv	seg_a87e79.csv	seg_d7967e.csv
# seg_0bc877.csv	seg_411225.csv	seg_753190.csv	seg_a88097.csv	seg_d7a805.csv
# seg_0be6ee.csv	seg_414d0f.csv	seg_753ba6.csv	seg_a88dde.csv	seg_d7ab50.csv
# seg_0c12cc.csv	seg_4185b3.csv	seg_7540f3.csv	seg_a8bb2f.csv	seg_d7f015.csv
# seg_0c1d3a.csv	seg_419531.csv	seg_75438e.csv	seg_a8ddf7.csv	seg_d7f53a.csv
# seg_0c247b.csv	seg_419b2a.csv	seg_755d50.csv	seg_a8e6df.csv	seg_d8014d.csv
# seg_0c3943.csv	seg_41a267.csv	seg_75654d.csv	seg_a8e71a.csv	seg_d83890.csv
# seg_0c4e31.csv	seg_41aadc.csv	seg_758374.csv	seg_a9089b.csv	seg_d85e2e.csv
# seg_0c74cf.csv	seg_41ab7e.csv	seg_758ca4.csv	seg_a91c03.csv	seg_d86eb6.csv
# seg_0c8502.csv	seg_41be18.csv	seg_759fb1.csv	seg_a93a88.csv	seg_d88da7.csv
# seg_0c89ce.csv	seg_41be7d.csv	seg_75a878.csv	seg_a96b47.csv	seg_d89369.csv
# seg_0c9aa8.csv	seg_41f45e.csv	seg_75c34b.csv	seg_a975df.csv	seg_d90c5f.csv
# seg_0cb81b.csv	seg_420bcc.csv	seg_75cd6a.csv	seg_a99161.csv	seg_d91492.csv
# seg_0cca14.csv	seg_420d4e.csv	seg_75dc3e.csv	seg_a99799.csv	seg_d9190c.csv
# seg_0cdcc8.csv	seg_421a96.csv	seg_75e669.csv	seg_a99be9.csv	seg_d9352b.csv
# seg_0cf651.csv	seg_421da1.csv	seg_75e93c.csv	seg_a9a820.csv	seg_d962cc.csv
# seg_0d0250.csv	seg_423ebe.csv	seg_75eb90.csv	seg_a9b957.csv	seg_d9750c.csv
# seg_0d04b9.csv	seg_425462.csv	seg_75ffc9.csv	seg_a9f80e.csv	seg_d9a2bb.csv
# seg_0d13a7.csv	seg_42648c.csv	seg_760d70.csv	seg_aa0180.csv	seg_d9b162.csv
# seg_0d434c.csv	seg_4280d9.csv	seg_76106f.csv	seg_aa1adf.csv	seg_d9bb68.csv
# seg_0d540e.csv	seg_428d66.csv	seg_762188.csv	seg_aa508a.csv	seg_d9ce67.csv
# seg_0d663a.csv	seg_42c4c9.csv	seg_762be4.csv	seg_aa78e0.csv	seg_d9d0e4.csv
# seg_0d6d68.csv	seg_42e7e8.csv	seg_7630c5.csv	seg_aa7a4b.csv	seg_d9dab4.csv
# seg_0d762e.csv	seg_42ff14.csv	seg_766e42.csv	seg_aa98cc.csv	seg_da21ee.csv
# seg_0d833c.csv	seg_430e66.csv	seg_76b76f.csv	seg_aa9b8e.csv	seg_da7c3b.csv
# seg_0dae4b.csv	seg_43383f.csv	seg_76c2fa.csv	seg_aaa2ae.csv	seg_da80c4.csv
# seg_0dc38f.csv	seg_434c96.csv	seg_76d16c.csv	seg_aabc52.csv	seg_da8b88.csv
# seg_0dcc40.csv	seg_43597f.csv	seg_76e914.csv	seg_aae025.csv	seg_dab0f9.csv
# seg_0df469.csv	seg_43c6f4.csv	seg_76f1af.csv	seg_ab001b.csv	seg_dad4f2.csv
# seg_0df75c.csv	seg_440106.csv	seg_76f3f2.csv	seg_ab15ad.csv	seg_db3446.csv
# seg_0dfe8c.csv	seg_4401d8.csv	seg_76f76d.csv	seg_ab2a78.csv	seg_db3a95.csv
# seg_0e1370.csv	seg_441c6d.csv	seg_774ad2.csv	seg_ab3f14.csv	seg_db3fbe.csv
# seg_0e1fbe.csv	seg_4435bd.csv	seg_77bf79.csv	seg_ab4bca.csv	seg_db4185.csv
# seg_0e3739.csv	seg_447972.csv	seg_77c546.csv	seg_ab644e.csv	seg_db606c.csv
# seg_0e3d44.csv	seg_447b8b.csv	seg_77db7b.csv	seg_ab70bd.csv	seg_db694a.csv
# seg_0e3ed2.csv	seg_447cb3.csv	seg_77dbe7.csv	seg_ab9654.csv	seg_db6d5f.csv
# seg_0e4833.csv	seg_44d3ca.csv	seg_77df38.csv	seg_aba501.csv	seg_db90c0.csv
# seg_0e7cc5.csv	seg_455b16.csv	seg_77e7bf.csv	seg_abaad2.csv	seg_dbbb44.csv
# seg_0e8b79.csv	seg_456149.csv	seg_77ea14.csv	seg_abb03a.csv	seg_dbc615.csv
# seg_0e9987.csv	seg_457234.csv	seg_77f9e3.csv	seg_abb06a.csv	seg_dbf3f2.csv
# seg_0e9bb3.csv	seg_45838b.csv	seg_77fe77.csv	seg_abc5fd.csv	seg_dc188b.csv
# seg_0eb333.csv	seg_4587bb.csv	seg_7848f8.csv	seg_abda04.csv	seg_dc1cf0.csv
# seg_0ebfd9.csv	seg_45a8a9.csv	seg_7862ed.csv	seg_abeca6.csv	seg_dc23c0.csv
# seg_0f565c.csv	seg_45b051.csv	seg_786ff6.csv	seg_ac45ae.csv	seg_dc4698.csv
# seg_0f74a3.csv	seg_45e062.csv	seg_78852d.csv	seg_ac5c61.csv	seg_dc5e63.csv
# seg_0f8961.csv	seg_45e4ed.csv	seg_78addc.csv	seg_ac68bb.csv	seg_dc6e94.csv
# seg_0fc67a.csv	seg_45e7ad.csv	seg_78d817.csv	seg_ac9de5.csv	seg_dc73b8.csv
# seg_0fca83.csv	seg_46012e.csv	seg_78db0a.csv	seg_acd715.csv	seg_dc7e0d.csv
# seg_0fd3ff.csv	seg_460436.csv	seg_78ded2.csv	seg_acf2f4.csv	seg_dca2c2.csv
# seg_1010ad.csv	seg_461ab5.csv	seg_78fc4b.csv	seg_ad3a44.csv	seg_dcb51d.csv
# seg_103b32.csv	seg_461b63.csv	seg_790108.csv	seg_ad3cf0.csv	seg_dcbe02.csv
# seg_105cd9.csv	seg_462c1d.csv	seg_7949da.csv	seg_ad591c.csv	seg_dcd9df.csv
# seg_1084af.csv	seg_464839.csv	seg_79c47a.csv	seg_ad759c.csv	seg_dcee28.csv
# seg_10a595.csv	seg_468bc9.csv	seg_79dc90.csv	seg_ad82ca.csv	seg_dceeca.csv
# seg_10c09d.csv	seg_468fdb.csv	seg_79e301.csv	seg_ad949a.csv	seg_dcf242.csv
# seg_10f3a6.csv	seg_46a42b.csv	seg_7a09ec.csv	seg_ada42c.csv	seg_dcfb4b.csv
# seg_112b81.csv	seg_46b84d.csv	seg_7a521c.csv	seg_ada81a.csv	seg_dd0b11.csv
# seg_1144bc.csv	seg_46c6d3.csv	seg_7a5243.csv	seg_ade769.csv	seg_dd4594.csv
# seg_114b79.csv	seg_46dd7c.csv	seg_7a9228.csv	seg_adf94a.csv	seg_dd699c.csv
# seg_115617.csv	seg_4729a7.csv	seg_7a9f2b.csv	seg_adf986.csv	seg_dd780d.csv
# seg_115a92.csv	seg_4743ab.csv	seg_7aeca4.csv	seg_ae32a6.csv	seg_dd8805.csv
# seg_11647f.csv	seg_4743fa.csv	seg_7b0936.csv	seg_ae3388.csv	seg_ddbadc.csv
# seg_117278.csv	seg_476700.csv	seg_7b2994.csv	seg_ae3d92.csv	seg_ddc800.csv
# seg_117ff4.csv	seg_476bdb.csv	seg_7b3017.csv	seg_ae42b3.csv	seg_ddd206.csv
# seg_11860f.csv	seg_477c83.csv	seg_7b5f90.csv	seg_ae9626.csv	seg_ddddf0.csv
# seg_1201e8.csv	seg_478327.csv	seg_7bb771.csv	seg_ae9761.csv	seg_de225c.csv
# seg_121446.csv	seg_47a48f.csv	seg_7bec10.csv	seg_aec276.csv	seg_de3237.csv
# seg_121cba.csv	seg_47d374.csv	seg_7bf143.csv	seg_aed434.csv	seg_de3d5e.csv
# seg_122ba9.csv	seg_47fed6.csv	seg_7c0376.csv	seg_aee7c0.csv	seg_de4e1d.csv
# seg_123dd4.csv	seg_482745.csv	seg_7c10c1.csv	seg_aee9bf.csv	seg_de8180.csv
# seg_12ac20.csv	seg_4848e3.csv	seg_7c2beb.csv	seg_aeeb31.csv	seg_de98fa.csv
# seg_12b9ba.csv	seg_484901.csv	seg_7c2c48.csv	seg_af1650.csv	seg_de9e32.csv
# seg_12ee6e.csv	seg_486973.csv	seg_7c6c31.csv	seg_af2472.csv	seg_df0df7.csv
# seg_130e17.csv	seg_48a4b3.csv	seg_7c88d1.csv	seg_af6204.csv	seg_df352f.csv
# seg_13468a.csv	seg_48a80c.csv	seg_7c9433.csv	seg_af703b.csv	seg_df45b0.csv
# seg_136285.csv	seg_48b545.csv	seg_7cb417.csv	seg_af959f.csv	seg_df8385.csv
# seg_136695.csv	seg_48feba.csv	seg_7cbb45.csv	seg_afa4a1.csv	seg_df8e0a.csv
# seg_137f8a.csv	seg_490092.csv	seg_7cd6b1.csv	seg_afadfb.csv	seg_df99d4.csv
# seg_138807.csv	seg_490d6e.csv	seg_7cdfe5.csv	seg_afca81.csv	seg_dff078.csv
# seg_13c2f0.csv	seg_492dc6.csv	seg_7ce9cb.csv	seg_afd665.csv	seg_e00465.csv
# seg_13e25f.csv	seg_49322d.csv	seg_7cef95.csv	seg_b00f05.csv	seg_e051bc.csv
# seg_140bc5.csv	seg_49336f.csv	seg_7d17eb.csv	seg_b02e31.csv	seg_e05de2.csv
# seg_141f34.csv	seg_495573.csv	seg_7d2535.csv	seg_b03de5.csv	seg_e067ab.csv
# seg_146926.csv	seg_496d07.csv	seg_7d2e57.csv	seg_b08e9d.csv	seg_e09301.csv
# seg_148698.csv	seg_496dad.csv	seg_7d65c7.csv	seg_b0a794.csv	seg_e0c329.csv
# seg_14ad27.csv	seg_49b0cb.csv	seg_7d718e.csv	seg_b0bf65.csv	seg_e0ce38.csv
# seg_14c054.csv	seg_49d84b.csv	seg_7d88e3.csv	seg_b0cf32.csv	seg_e0cfd4.csv
# seg_14c371.csv	seg_49fdf0.csv	seg_7d994f.csv	seg_b0d251.csv	seg_e0f296.csv
# seg_14c435.csv	seg_4a2525.csv	seg_7ddc30.csv	seg_b0f9cd.csv	seg_e10d3b.csv
# seg_14c89d.csv	seg_4a6096.csv	seg_7df3dd.csv	seg_b108c9.csv	seg_e13bd8.csv
# seg_14c8ce.csv	seg_4a719c.csv	seg_7e3b3e.csv	seg_b13220.csv	seg_e14149.csv
# seg_14d1d3.csv	seg_4a91a9.csv	seg_7e9eb7.csv	seg_b13fb9.csv	seg_e1468f.csv
# seg_14f5f0.csv	seg_4a9e6b.csv	seg_7eb108.csv	seg_b197e2.csv	seg_e15cb9.csv
# seg_151368.csv	seg_4a9e8d.csv	seg_7ebdc3.csv	seg_b1a35c.csv	seg_e197b8.csv
# seg_151d92.csv	seg_4ab7bf.csv	seg_7ed2dd.csv	seg_b1b95e.csv	seg_e1a9e0.csv
# seg_153d6a.csv	seg_4abc29.csv	seg_7ef97b.csv	seg_b1fea8.csv	seg_e1daa0.csv
# seg_154361.csv	seg_4acc4b.csv	seg_7efdd5.csv	seg_b20487.csv	seg_e1f045.csv
# seg_1562cb.csv	seg_4ad5a2.csv	seg_7f3ab0.csv	seg_b21273.csv	seg_e1f081.csv
# seg_158691.csv	seg_4ad674.csv	seg_7f5b6f.csv	seg_b23489.csv	seg_e20d76.csv
# seg_158764.csv	seg_4adeda.csv	seg_7f786b.csv	seg_b253ee.csv	seg_e217fc.csv
# seg_15adff.csv	seg_4ae37c.csv	seg_7f93b2.csv	seg_b25dde.csv	seg_e2209b.csv
# seg_15bf25.csv	seg_4ae712.csv	seg_7f9b3a.csv	seg_b26368.csv	seg_e24496.csv
# seg_15c9f9.csv	seg_4b0839.csv	seg_7fa6ec.csv	seg_b284b2.csv	seg_e24f69.csv
# seg_161aeb.csv	seg_4b4c91.csv	seg_7fac26.csv	seg_b291c0.csv	seg_e256bd.csv
# seg_161f5f.csv	seg_4b4ffb.csv	seg_7fd3a3.csv	seg_b2b29d.csv	seg_e25aca.csv
# seg_162fc4.csv	seg_4b8044.csv	seg_7fd6b7.csv	seg_b2b331.csv	seg_e266f4.csv
# seg_16566c.csv	seg_4b953a.csv	seg_80211c.csv	seg_b2e045.csv	seg_e27c0a.csv
# seg_166f70.csv	seg_4ba3d1.csv	seg_804fb5.csv	seg_b31961.csv	seg_e29670.csv
# seg_168d1c.csv	seg_4c067a.csv	seg_80622d.csv	seg_b32d1d.csv	seg_e2b8b1.csv
# seg_16a270.csv	seg_4c12b2.csv	seg_807901.csv	seg_b35174.csv	seg_e2c82c.csv
# seg_16c3a7.csv	seg_4c18e2.csv	seg_80b9b4.csv	seg_b36650.csv	seg_e3005e.csv
# seg_17067e.csv	seg_4c3a2b.csv	seg_80fb86.csv	seg_b36c8a.csv	seg_e30e44.csv
# seg_170684.csv	seg_4c4995.csv	seg_812962.csv	seg_b378bc.csv	seg_e30ef5.csv
# seg_170a0c.csv	seg_4c65e6.csv	seg_812a50.csv	seg_b3883e.csv	seg_e34052.csv
# seg_176542.csv	seg_4c8db6.csv	seg_813aab.csv	seg_b3cf21.csv	seg_e37b8e.csv
# seg_17799c.csv	seg_4ca6de.csv	seg_814b1f.csv	seg_b3d886.csv	seg_e3b1f1.csv
# seg_179d90.csv	seg_4cb0d7.csv	seg_816b7a.csv	seg_b402ac.csv	seg_e3ca24.csv
# seg_17adc0.csv	seg_4cb9c6.csv	seg_818382.csv	seg_b41d3c.csv	seg_e3cf1a.csv
# seg_17d1ff.csv	seg_4ce234.csv	seg_81a8ea.csv	seg_b42170.csv	seg_e3d751.csv
# seg_17e596.csv	seg_4d0008.csv	seg_81bebd.csv	seg_b4402d.csv	seg_e3dafa.csv
# seg_180481.csv	seg_4d0041.csv	seg_81c1a6.csv	seg_b44c2e.csv	seg_e3e762.csv
# seg_18096a.csv	seg_4d0c45.csv	seg_81c432.csv	seg_b47c19.csv	seg_e40348.csv
# seg_1815fe.csv	seg_4d18f4.csv	seg_81f798.csv	seg_b4c040.csv	seg_e405fe.csv
# seg_1827c5.csv	seg_4d2671.csv	seg_8200d2.csv	seg_b4cb44.csv	seg_e40d64.csv
# seg_184222.csv	seg_4d53c2.csv	seg_82303e.csv	seg_b4f7a8.csv	seg_e41fc9.csv
# seg_185ad6.csv	seg_4d5a4a.csv	seg_82316b.csv	seg_b50239.csv	seg_e47d2b.csv
# seg_18d1d0.csv	seg_4d7c56.csv	seg_8244bf.csv	seg_b51380.csv	seg_e481c7.csv
# seg_18d307.csv	seg_4d8f0f.csv	seg_82456a.csv	seg_b51b7c.csv	seg_e48c23.csv
# seg_18f633.csv	seg_4db886.csv	seg_826208.csv	seg_b52710.csv	seg_e49750.csv
# seg_18f853.csv	seg_4db997.csv	seg_827804.csv	seg_b52add.csv	seg_e4c15a.csv
# seg_18fb65.csv	seg_4dbbd1.csv	seg_827a21.csv	seg_b52dac.csv	seg_e4f203.csv
# seg_193404.csv	seg_4ddddc.csv	seg_827c07.csv	seg_b54024.csv	seg_e4f403.csv
# seg_19515c.csv	seg_4dfa03.csv	seg_82c138.csv	seg_b568c6.csv	seg_e50f16.csv
# seg_195eda.csv	seg_4e0c4a.csv	seg_82ce27.csv	seg_b57e76.csv	seg_e52f8c.csv
# seg_1969c8.csv	seg_4e2c66.csv	seg_82d7b6.csv	seg_b5804a.csv	seg_e53a52.csv
# seg_19b08e.csv	seg_4e3bd7.csv	seg_830cff.csv	seg_b58542.csv	seg_e54932.csv
# seg_19b9dd.csv	seg_4e627b.csv	seg_8310ea.csv	seg_b5a447.csv	seg_e5750a.csv
# seg_19e1ff.csv	seg_4e9646.csv	seg_8324a4.csv	seg_b5aee9.csv	seg_e59dca.csv
# seg_19ec5c.csv	seg_4ea3fa.csv	seg_8328f5.csv	seg_b6254c.csv	seg_e5b510.csv
# seg_1a0e94.csv	seg_4ea81c.csv	seg_832a4d.csv	seg_b63de1.csv	seg_e5c033.csv
# seg_1a0eca.csv	seg_4eb127.csv	seg_8344ee.csv	seg_b64c9c.csv	seg_e5deec.csv
# seg_1a671a.csv	seg_4eeaef.csv	seg_8353f5.csv	seg_b66b87.csv	seg_e5e238.csv
# seg_1a791c.csv	seg_4eef28.csv	seg_836aac.csv	seg_b686e5.csv	seg_e5f9ec.csv
# seg_1a8e06.csv	seg_4f48b4.csv	seg_836ef0.csv	seg_b687fc.csv	seg_e5fbc1.csv
# seg_1a8f0d.csv	seg_4f5931.csv	seg_83bef8.csv	seg_b691c5.csv	seg_e60719.csv
# seg_1a8f2c.csv	seg_4f76a2.csv	seg_83cb2c.csv	seg_b69455.csv	seg_e6307f.csv
# seg_1abcaf.csv	seg_4f83a3.csv	seg_83dc2e.csv	seg_b695b3.csv	seg_e64dfa.csv
# seg_1ac9e2.csv	seg_4fa87d.csv	seg_83ef67.csv	seg_b6bdaa.csv	seg_e65e69.csv
# seg_1ae362.csv	seg_4fce5b.csv	seg_83f476.csv	seg_b6c10d.csv	seg_e66697.csv
# seg_1afa29.csv	seg_4fd191.csv	seg_83f89e.csv	seg_b6cb2b.csv	seg_e6b236.csv
# seg_1b08a4.csv	seg_500108.csv	seg_83f928.csv	seg_b72413.csv	seg_e6bd3f.csv
# seg_1b1ad8.csv	seg_5009d9.csv	seg_8456d3.csv	seg_b735a5.csv	seg_e6c973.csv
# seg_1b2298.csv	seg_500c80.csv	seg_845a2a.csv	seg_b77bf5.csv	seg_e6e1df.csv
# seg_1b78af.csv	seg_502fab.csv	seg_8472f3.csv	seg_b782c7.csv	seg_e6e24e.csv
# seg_1baf33.csv	seg_507065.csv	seg_848695.csv	seg_b78883.csv	seg_e71dda.csv
# seg_1bd38e.csv	seg_5090fa.csv	seg_84a65d.csv	seg_b7a8a1.csv	seg_e72f10.csv
# seg_1bf7b3.csv	seg_509d55.csv	seg_84b9d9.csv	seg_b7b098.csv	seg_e742dc.csv
# seg_1c401b.csv	seg_50a667.csv	seg_84c7fb.csv	seg_b7da0a.csv	seg_e76e6e.csv
# seg_1c4c5b.csv	seg_50b048.csv	seg_84fc12.csv	seg_b7eeb6.csv	seg_e7ac12.csv
# seg_1c4e72.csv	seg_50e270.csv	seg_8509db.csv	seg_b80358.csv	seg_e7ced6.csv
# seg_1c849d.csv	seg_511d25.csv	seg_850d95.csv	seg_b80366.csv	seg_e7d1f8.csv
# seg_1c904f.csv	seg_512b3e.csv	seg_8515fd.csv	seg_b80b89.csv	seg_e7d3e7.csv
# seg_1c929e.csv	seg_514543.csv	seg_853302.csv	seg_b8141c.csv	seg_e80726.csv
# seg_1cb942.csv	seg_5147e1.csv	seg_854d91.csv	seg_b853c1.csv	seg_e81b50.csv
# seg_1cd352.csv	seg_514b85.csv	seg_857304.csv	seg_b853f8.csv	seg_e8385f.csv
# seg_1cf1b5.csv	seg_5165a4.csv	seg_85762d.csv	seg_b86ce1.csv	seg_e85f55.csv
# seg_1d044c.csv	seg_517345.csv	seg_8599ec.csv	seg_b8725b.csv	seg_e86e44.csv
# seg_1d11e5.csv	seg_517425.csv	seg_85c1c0.csv	seg_b8745c.csv	seg_e86ed1.csv
# seg_1d596d.csv	seg_51865e.csv	seg_85e90e.csv	seg_b87cf5.csv	seg_e86f77.csv
# seg_1d980f.csv	seg_518b1e.csv	seg_85e9c6.csv	seg_b88baa.csv	seg_e877a5.csv
# seg_1da819.csv	seg_51b68c.csv	seg_85fb0a.csv	seg_b89218.csv	seg_e8a2c4.csv
# seg_1db443.csv	seg_51f0a2.csv	seg_864fcf.csv	seg_b89e47.csv	seg_e8a4f4.csv
# seg_1db8e8.csv	seg_51f6fd.csv	seg_8658b3.csv	seg_b8b72f.csv	seg_e8ac98.csv
# seg_1dec9c.csv	seg_521a88.csv	seg_86720f.csv	seg_b8bb87.csv	seg_e8ad6b.csv
# seg_1e0523.csv	seg_523945.csv	seg_8681aa.csv	seg_b8fd73.csv	seg_e8b2b3.csv
# seg_1e0b82.csv	seg_524b39.csv	seg_86892f.csv	seg_b91011.csv	seg_e8bcde.csv
# seg_1e572b.csv	seg_5254ce.csv	seg_868c85.csv	seg_b917b5.csv	seg_e8ce6a.csv
# seg_1e617a.csv	seg_5255c0.csv	seg_86cfe9.csv	seg_b91ae2.csv	seg_e8d02f.csv
# seg_1e61d6.csv	seg_52636c.csv	seg_86d847.csv	seg_b9361a.csv	seg_e90c0d.csv
# seg_1e677e.csv	seg_529be4.csv	seg_86e874.csv	seg_b9365c.csv	seg_e92526.csv
# seg_1eae76.csv	seg_529c99.csv	seg_87232d.csv	seg_b947ae.csv	seg_e9272e.csv
# seg_1ebe6b.csv	seg_52c139.csv	seg_876904.csv	seg_b95010.csv	seg_e96140.csv
# seg_1ece48.csv	seg_530a02.csv	seg_8773cf.csv	seg_b95a77.csv	seg_e98217.csv
# seg_1eeb8f.csv	seg_53103b.csv	seg_8777bd.csv	seg_b9619c.csv	seg_e9a09f.csv
# seg_1ef708.csv	seg_5311d1.csv	seg_8785e2.csv	seg_b9ad7f.csv	seg_e9aa44.csv
# seg_1f1e60.csv	seg_533613.csv	seg_878d2c.csv	seg_b9bdd7.csv	seg_e9df42.csv
# seg_1f3d44.csv	seg_53498a.csv	seg_87a616.csv	seg_b9d8a0.csv	seg_e9e65b.csv
# seg_1f3ede.csv	seg_53a557.csv	seg_87a67a.csv	seg_b9de03.csv	seg_ea0091.csv
# seg_1f5240.csv	seg_53a5fd.csv	seg_87e4e8.csv	seg_b9ec4b.csv	seg_ea05c1.csv
# seg_1f7cf8.csv	seg_53bdf5.csv	seg_87f6c8.csv	seg_ba0485.csv	seg_ea096b.csv
# seg_1f9aed.csv	seg_53caf1.csv	seg_8826f4.csv	seg_ba1d68.csv	seg_ea098b.csv
# seg_1fa983.csv	seg_53d818.csv	seg_885f53.csv	seg_ba2c48.csv	seg_ea4d3a.csv
# seg_1fc7ab.csv	seg_53e645.csv	seg_8866f0.csv	seg_ba3c47.csv	seg_ea78c0.csv
# seg_1fe311.csv	seg_53fa13.csv	seg_88a81d.csv	seg_ba3e74.csv	seg_ea8270.csv
# seg_2005a7.csv	seg_5407b0.csv	seg_88b289.csv	seg_ba4ea3.csv	seg_ea9d37.csv
# seg_2018c8.csv	seg_5445bc.csv	seg_890181.csv	seg_ba5e7e.csv	seg_ea9fa4.csv
# seg_204dc6.csv	seg_54490e.csv	seg_89791c.csv	seg_ba83da.csv	seg_eaa0ec.csv
# seg_208ba5.csv	seg_545fda.csv	seg_89885a.csv	seg_ba941e.csv	seg_eabb2c.csv
# seg_2099f4.csv	seg_5467c8.csv	seg_899bf0.csv	seg_ba98dc.csv	seg_eacccf.csv
# seg_20a990.csv	seg_546864.csv	seg_89b090.csv	seg_ba9dbf.csv	seg_ead30e.csv
# seg_20b8d0.csv	seg_5470ca.csv	seg_89d8a0.csv	seg_baa745.csv	seg_eb0b19.csv
# seg_20cbac.csv	seg_5495ca.csv	seg_89e207.csv	seg_bb171f.csv	seg_eb1d6e.csv
# seg_20cc25.csv	seg_54af0d.csv	seg_89eed6.csv	seg_bb180c.csv	seg_eb2e11.csv
# seg_20d9de.csv	seg_54b0ee.csv	seg_89f975.csv	seg_bb2d77.csv	seg_eb32bc.csv
# seg_20e9ad.csv	seg_54d0f3.csv	seg_8a3306.csv	seg_bb5e15.csv	seg_eb47a9.csv
# seg_210388.csv	seg_55239a.csv	seg_8a41bf.csv	seg_bb6904.csv	seg_eb692c.csv
# seg_211299.csv	seg_552b8e.csv	seg_8a6b0e.csv	seg_bb6fcb.csv	seg_eb7595.csv
# seg_211486.csv	seg_5559d9.csv	seg_8a7201.csv	seg_bb92b1.csv	seg_eb7f91.csv
# seg_214492.csv	seg_555f63.csv	seg_8a8220.csv	seg_bbb01e.csv	seg_eba22d.csv
# seg_217eed.csv	seg_5597ed.csv	seg_8a8375.csv	seg_bbbc30.csv	seg_ebb79f.csv
# seg_218049.csv	seg_55a0c3.csv	seg_8ab3a7.csv	seg_bbf805.csv	seg_ebd77b.csv
# seg_21eebb.csv	seg_55a9a4.csv	seg_8ae847.csv	seg_bbfd4e.csv	seg_ebe36c.csv
# seg_21faa9.csv	seg_55b566.csv	seg_8aeb99.csv	seg_bc07c8.csv	seg_ebec3e.csv
# seg_222c5f.csv	seg_55d50b.csv	seg_8b39c4.csv	seg_bc1d67.csv	seg_ec0e7b.csv
# seg_225320.csv	seg_561cf4.csv	seg_8b798b.csv	seg_bc2186.csv	seg_ec4645.csv
# seg_226e60.csv	seg_563059.csv	seg_8baeab.csv	seg_bc437b.csv	seg_ec73d5.csv
# seg_229eda.csv	seg_5639b3.csv	seg_8bc20c.csv	seg_bca500.csv	seg_ec973c.csv
# seg_22e509.csv	seg_566efe.csv	seg_8bde47.csv	seg_bcc8f1.csv	seg_eca2eb.csv
# seg_2313d1.csv	seg_56e3e7.csv	seg_8be2da.csv	seg_bce23c.csv	seg_ecaef0.csv
# seg_232559.csv	seg_56e6f1.csv	seg_8be76c.csv	seg_bce305.csv	seg_eccb17.csv
# seg_23323e.csv	seg_56ebc7.csv	seg_8bec6f.csv	seg_bcf2d9.csv	seg_ecdca4.csv
# seg_2367fb.csv	seg_570a20.csv	seg_8bf229.csv	seg_bcf6af.csv	seg_ecf28d.csv
# seg_238242.csv	seg_570d69.csv	seg_8c0114.csv	seg_bcfad6.csv	seg_ecf81b.csv
# seg_2383c2.csv	seg_572172.csv	seg_8c1760.csv	seg_bd00c4.csv	seg_ed07b0.csv
# seg_2396a2.csv	seg_5759c9.csv	seg_8c1cca.csv	seg_bd2b0c.csv	seg_ed3e4c.csv
# seg_23b123.csv	seg_5765b6.csv	seg_8c1e7d.csv	seg_bd31bf.csv	seg_ed52ac.csv
# seg_23bdf9.csv	seg_578e84.csv	seg_8c341c.csv	seg_bd40f2.csv	seg_ed7741.csv
# seg_23c947.csv	seg_57908c.csv	seg_8c6d4e.csv	seg_bd4d30.csv	seg_ed7dee.csv
# seg_23efb0.csv	seg_57b6c0.csv	seg_8c6e34.csv	seg_bd5022.csv	seg_ed7f69.csv
# seg_23f823.csv	seg_57dd68.csv	seg_8cd159.csv	seg_bd629b.csv	seg_edda79.csv
# seg_23fe27.csv	seg_57ea44.csv	seg_8cdf83.csv	seg_bd6f5f.csv	seg_edecaa.csv
# seg_241266.csv	seg_580b65.csv	seg_8ce632.csv	seg_bd7109.csv	seg_ee1cfc.csv
# seg_24157a.csv	seg_581fac.csv	seg_8cf573.csv	seg_bdae02.csv	seg_ee2781.csv
# seg_24458d.csv	seg_585872.csv	seg_8d030a.csv	seg_bdf84b.csv	seg_ee4479.csv
# seg_2465ce.csv	seg_586726.csv	seg_8d135f.csv	seg_be0cdc.csv	seg_ee4ae5.csv
# seg_247262.csv	seg_586c0f.csv	seg_8d3a9d.csv	seg_be0dfa.csv	seg_ee7224.csv
# seg_24ba8d.csv	seg_5887a8.csv	seg_8d4435.csv	seg_be19e2.csv	seg_ee87e2.csv
# seg_24c078.csv	seg_588f61.csv	seg_8d4965.csv	seg_be30ce.csv	seg_ee8f87.csv
# seg_24c1c9.csv	seg_58d52d.csv	seg_8d5113.csv	seg_be4612.csv	seg_eea20e.csv
# seg_24e071.csv	seg_58e74b.csv	seg_8d6578.csv	seg_be62ef.csv	seg_eebbc2.csv
# seg_24f338.csv	seg_58e9f9.csv	seg_8d6a7d.csv	seg_be65f2.csv	seg_eee89d.csv
# seg_257b8a.csv	seg_58ea74.csv	seg_8da61a.csv	seg_be811d.csv	seg_eefd4a.csv
# seg_2597af.csv	seg_59058a.csv	seg_8db6f0.csv	seg_beb650.csv	seg_ef24bd.csv
# seg_259c63.csv	seg_590fa5.csv	seg_8dcf3c.csv	seg_beda44.csv	seg_ef27c8.csv
# seg_259d65.csv	seg_591954.csv	seg_8dd2ab.csv	seg_bee792.csv	seg_ef47c4.csv
# seg_259dd3.csv	seg_5924f5.csv	seg_8dd3ba.csv	seg_bf1294.csv	seg_ef644a.csv
# seg_25aa9f.csv	seg_592807.csv	seg_8dfc7e.csv	seg_bf1430.csv	seg_ef660a.csv
# seg_25ab3f.csv	seg_593c34.csv	seg_8dfd7a.csv	seg_bf1a72.csv	seg_ef74dc.csv
# seg_25b38a.csv	seg_5965d8.csv	seg_8e5704.csv	seg_bf2d1f.csv	seg_ef779d.csv
# seg_25c8dc.csv	seg_596ae3.csv	seg_8e6a3f.csv	seg_bf4bf2.csv	seg_ef9105.csv
# seg_25cca7.csv	seg_5975f4.csv	seg_8e7194.csv	seg_bf4ec0.csv	seg_efb639.csv
# seg_25e76d.csv	seg_597bd6.csv	seg_8e7fca.csv	seg_bf58ce.csv	seg_efbf3e.csv
# seg_26049e.csv	seg_59818b.csv	seg_8ebdea.csv	seg_bf7224.csv	seg_efc5fb.csv
# seg_263deb.csv	seg_59cd7d.csv	seg_8f1127.csv	seg_bfdd14.csv	seg_efd9ec.csv
# seg_263fb3.csv	seg_59cfdb.csv	seg_8f25b0.csv	seg_bfe0b6.csv	seg_f003ca.csv
# seg_2642d0.csv	seg_59d484.csv	seg_8f3247.csv	seg_bff05e.csv	seg_f01368.csv
# seg_2642d4.csv	seg_59de0b.csv	seg_8f3dfe.csv	seg_bff392.csv	seg_f0181d.csv
# seg_264c7d.csv	seg_59e1db.csv	seg_8f4654.csv	seg_c01a57.csv	seg_f02d32.csv
# seg_266805.csv	seg_59eb97.csv	seg_8f4781.csv	seg_c01d9a.csv	seg_f056d8.csv
# seg_266c6e.csv	seg_5a0479.csv	seg_8f5589.csv	seg_c01f63.csv	seg_f0574b.csv
# seg_266d4e.csv	seg_5a1adb.csv	seg_8f592b.csv	seg_c0260d.csv	seg_f073e2.csv
# seg_268249.csv	seg_5a242e.csv	seg_8f6284.csv	seg_c047b7.csv	seg_f0ce4a.csv
# seg_268625.csv	seg_5a67b5.csv	seg_8fb0d0.csv	seg_c05a7d.csv	seg_f0cedb.csv
# seg_268956.csv	seg_5a947e.csv	seg_8fb29e.csv	seg_c07b7c.csv	seg_f0d278.csv
# seg_26a2a0.csv	seg_5abfdd.csv	seg_8fb828.csv	seg_c08d36.csv	seg_f0db55.csv
# seg_26cba3.csv	seg_5ad847.csv	seg_8fc754.csv	seg_c09a41.csv	seg_f11620.csv
# seg_26edaa.csv	seg_5b392b.csv	seg_8fd465.csv	seg_c0c0ed.csv	seg_f11f77.csv
# seg_2700bd.csv	seg_5b7325.csv	seg_902074.csv	seg_c0d7da.csv	seg_f165f6.csv
# seg_272a47.csv	seg_5b8c39.csv	seg_902bc1.csv	seg_c0e1b9.csv	seg_f19f8e.csv
# seg_274a1a.csv	seg_5bc0b0.csv	seg_903aba.csv	seg_c0ea9f.csv	seg_f1a771.csv
# seg_2774c4.csv	seg_5bd9ae.csv	seg_907c52.csv	seg_c106ca.csv	seg_f1b916.csv
# seg_279725.csv	seg_5bdb47.csv	seg_90a0be.csv	seg_c10a58.csv	seg_f1f5b9.csv
# seg_27a282.csv	seg_5bfbf0.csv	seg_90b174.csv	seg_c11828.csv	seg_f21a22.csv
# seg_27b7c8.csv	seg_5c0929.csv	seg_90bf60.csv	seg_c11a4f.csv	seg_f21bf4.csv
# seg_27db4d.csv	seg_5c1a4d.csv	seg_90c258.csv	seg_c12d7d.csv	seg_f22163.csv
# seg_27de37.csv	seg_5c530f.csv	seg_90e904.csv	seg_c146a8.csv	seg_f229bf.csv
# seg_27f532.csv	seg_5c57a8.csv	seg_90ec68.csv	seg_c15d21.csv	seg_f24292.csv
# seg_27ff17.csv	seg_5c8ae5.csv	seg_90ef18.csv	seg_c17817.csv	seg_f2750c.csv
# seg_280863.csv	seg_5c9077.csv	seg_911066.csv	seg_c179f8.csv	seg_f2a20d.csv
# seg_280e3b.csv	seg_5cd98b.csv	seg_9122aa.csv	seg_c183e4.csv	seg_f2ae5e.csv
# seg_284223.csv	seg_5cde88.csv	seg_913ffc.csv	seg_c186dc.csv	seg_f2b0c5.csv
# seg_284923.csv	seg_5cfba9.csv	seg_914a62.csv	seg_c18d5a.csv	seg_f2cb5e.csv
# seg_287e60.csv	seg_5cfdc4.csv	seg_91596c.csv	seg_c1fe9a.csv	seg_f2f5a3.csv
# seg_287fef.csv	seg_5d333e.csv	seg_915b3e.csv	seg_c20a27.csv	seg_f3063a.csv
# seg_288001.csv	seg_5d45db.csv	seg_91607c.csv	seg_c20c06.csv	seg_f30b2f.csv
# seg_2883ec.csv	seg_5d92af.csv	seg_919a6a.csv	seg_c21723.csv	seg_f30f0c.csv
# seg_289d99.csv	seg_5d94b2.csv	seg_919c5c.csv	seg_c21d60.csv	seg_f322b1.csv
# seg_28fc32.csv	seg_5e020f.csv	seg_91bf8c.csv	seg_c22bd4.csv	seg_f342a3.csv
# seg_29022f.csv	seg_5e0902.csv	seg_91cff2.csv	seg_c23429.csv	seg_f34877.csv
# seg_2916e3.csv	seg_5e1bba.csv	seg_91eaeb.csv	seg_c23641.csv	seg_f383fb.csv
# seg_293dbf.csv	seg_5e541f.csv	seg_91f512.csv	seg_c243a6.csv	seg_f3c578.csv
# seg_293dc2.csv	seg_5e635a.csv	seg_91f664.csv	seg_c24946.csv	seg_f43730.csv
# seg_29475f.csv	seg_5e668a.csv	seg_91fc29.csv	seg_c25855.csv	seg_f43ab6.csv
# seg_295b1c.csv	seg_5e70a7.csv	seg_920132.csv	seg_c267a5.csv	seg_f455bc.csv
# seg_2977cd.csv	seg_5e7abf.csv	seg_92092a.csv	seg_c26fb4.csv	seg_f46cc1.csv
# seg_29a073.csv	seg_5e8ef4.csv	seg_922914.csv	seg_c27591.csv	seg_f48363.csv
# seg_29acb7.csv	seg_5eb380.csv	seg_922990.csv	seg_c2a0c8.csv	seg_f48db9.csv
# seg_29c772.csv	seg_5ec0e3.csv	seg_92310f.csv	seg_c2b8f7.csv	seg_f4ad4b.csv
# seg_29c906.csv	seg_5ed47e.csv	seg_929ded.csv	seg_c3507f.csv	seg_f4d644.csv
# seg_29d497.csv	seg_5ef47e.csv	seg_92a5f1.csv	seg_c35940.csv	seg_f52cdc.csv
# seg_29d4c6.csv	seg_5f0a92.csv	seg_92af10.csv	seg_c365de.csv	seg_f5406b.csv
# seg_29e799.csv	seg_5f24d3.csv	seg_92b095.csv	seg_c3836b.csv	seg_f579ba.csv
# seg_2a0ace.csv	seg_5f352e.csv	seg_92bd37.csv	seg_c3f672.csv	seg_f57ca1.csv
# seg_2a0afc.csv	seg_5f355e.csv	seg_92be9f.csv	seg_c3f8d7.csv	seg_f59974.csv
# seg_2a0dc0.csv	seg_5f46a5.csv	seg_931244.csv	seg_c41d1d.csv	seg_f5a4ee.csv
# seg_2a2f1e.csv	seg_5f7fd9.csv	seg_93211c.csv	seg_c42490.csv	seg_f5a6ab.csv
# seg_2a4551.csv	seg_5fe414.csv	seg_932828.csv	seg_c42952.csv	seg_f5d2dd.csv
# seg_2a6343.csv	seg_60277f.csv	seg_934087.csv	seg_c44bbc.csv	seg_f5e682.csv
# seg_2a8351.csv	seg_6074f9.csv	seg_939f5c.csv	seg_c46ce6.csv	seg_f60872.csv
# seg_2aa101.csv	seg_607559.csv	seg_93d864.csv	seg_c472cf.csv	seg_f618a8.csv
# seg_2abd33.csv	seg_60ab20.csv	seg_93f935.csv	seg_c47bdc.csv	seg_f61b0e.csv
# seg_2b2cb3.csv	seg_60b696.csv	seg_941759.csv	seg_c4af54.csv	seg_f639cd.csv
# seg_2b372b.csv	seg_60dacd.csv	seg_943de0.csv	seg_c5064e.csv	seg_f639ec.csv
# seg_2b4959.csv	seg_60df2a.csv	seg_944c98.csv	seg_c509ff.csv	seg_f650cc.csv
# seg_2b6d52.csv	seg_610379.csv	seg_945bc8.csv	seg_c522f8.csv	seg_f6659e.csv
# seg_2ba79a.csv	seg_61219c.csv	seg_946d71.csv	seg_c5256d.csv	seg_f66db1.csv
# seg_2bcbde.csv	seg_613702.csv	seg_946d9a.csv	seg_c52ae6.csv	seg_f679c6.csv
# seg_2be983.csv	seg_614b50.csv	seg_947700.csv	seg_c5325c.csv	seg_f67ce2.csv
# seg_2bf5be.csv	seg_6153ca.csv	seg_9485c0.csv	seg_c550b1.csv	seg_f6828d.csv
# seg_2bf9dd.csv	seg_6167f0.csv	seg_94a133.csv	seg_c565bd.csv	seg_f69c38.csv
# seg_2c3203.csv	seg_616c8b.csv	seg_94aa0a.csv	seg_c571ef.csv	seg_f6a217.csv
# seg_2c5e9f.csv	seg_61b50d.csv	seg_94c48c.csv	seg_c588c1.csv	seg_f6abc5.csv
# seg_2c6011.csv	seg_61f504.csv	seg_94d150.csv	seg_c58ca5.csv	seg_f6b70c.csv
# seg_2c69e4.csv	seg_620ee4.csv	seg_94d573.csv	seg_c5abaa.csv	seg_f6bae8.csv
# seg_2c762c.csv	seg_622e9d.csv	seg_94ecad.csv	seg_c5c455.csv	seg_f6c0cb.csv
# seg_2cac57.csv	seg_62331a.csv	seg_950048.csv	seg_c5c6ea.csv	seg_f6c928.csv
# seg_2cadc0.csv	seg_6262c4.csv	seg_952faa.csv	seg_c5dada.csv	seg_f6cfd4.csv
# seg_2cdbe3.csv	seg_629822.csv	seg_95357d.csv	seg_c5dee4.csv	seg_f6d51b.csv
# seg_2d3828.csv	seg_62a403.csv	seg_95644e.csv	seg_c5f986.csv	seg_f6e1ca.csv
# seg_2d402d.csv	seg_62c582.csv	seg_957ece.csv	seg_c5fc3b.csv	seg_f6e89f.csv
# seg_2d427f.csv	seg_63130f.csv	seg_95b321.csv	seg_c5fc87.csv	seg_f6f523.csv
# seg_2d5544.csv	seg_633651.csv	seg_95f45e.csv	seg_c607eb.csv	seg_f6f683.csv
# seg_2d7cc4.csv	seg_634180.csv	seg_961d02.csv	seg_c60dca.csv	seg_f7050a.csv
# seg_2d92f0.csv	seg_634f05.csv	seg_961ddf.csv	seg_c60f1d.csv	seg_f70b66.csv
# seg_2db7dc.csv	seg_635770.csv	seg_9626a4.csv	seg_c627fc.csv	seg_f71db8.csv
# seg_2dc6ff.csv	seg_63582a.csv	seg_96642e.csv	seg_c62a06.csv	seg_f7290f.csv
# seg_2dccec.csv	seg_63c13d.csv	seg_966f3d.csv	seg_c65135.csv	seg_f734c8.csv
# seg_2dcd3a.csv	seg_63c518.csv	seg_967ae4.csv	seg_c654e7.csv	seg_f741af.csv
# seg_2dcd84.csv	seg_63c8e4.csv	seg_96cd5d.csv	seg_c666dd.csv	seg_f77ee5.csv
# seg_2dfb91.csv	seg_63c983.csv	seg_96dab2.csv	seg_c671f7.csv	seg_f7d792.csv
# seg_2e2372.csv	seg_63c9a3.csv	seg_96db5e.csv	seg_c6b514.csv	seg_f7de40.csv
# seg_2e50fb.csv	seg_63d651.csv	seg_96fa35.csv	seg_c6c29f.csv	seg_f80e44.csv
# seg_2e64af.csv	seg_6422d1.csv	seg_970b35.csv	seg_c6f0a2.csv	seg_f83d28.csv
# seg_2e71dd.csv	seg_643d1f.csv	seg_970e86.csv	seg_c6f533.csv	seg_f865be.csv
# seg_2e88dd.csv	seg_643f86.csv	seg_974049.csv	seg_c6f9c2.csv	seg_f86c41.csv
# seg_2e917f.csv	seg_64bcb9.csv	seg_9757ac.csv	seg_c703be.csv	seg_f88d4a.csv
# seg_2e9a47.csv	seg_64be5d.csv	seg_979a8f.csv	seg_c70fde.csv	seg_f8db0a.csv
# seg_2ea616.csv	seg_64be91.csv	seg_97a161.csv	seg_c714d0.csv	seg_f8dd7e.csv
# seg_2eccb9.csv	seg_64daae.csv	seg_97ad82.csv	seg_c73df6.csv	seg_f931de.csv
# seg_2ece02.csv	seg_64dcf0.csv	seg_97d9ed.csv	seg_c747ad.csv	seg_f93ce5.csv
# seg_2ed79b.csv	seg_64f8dc.csv	seg_97e4a9.csv	seg_c747b4.csv	seg_f95fd3.csv
# seg_2eddf6.csv	seg_650de2.csv	seg_9802c3.csv	seg_c7a3bc.csv	seg_f96d0e.csv
# seg_2ee95c.csv	seg_651808.csv	seg_9825e0.csv	seg_c7a401.csv	seg_f96d5a.csv
# seg_2efd5c.csv	seg_652cc2.csv	seg_983778.csv	seg_c7a579.csv	seg_f97274.csv
# seg_2f1664.csv	seg_655780.csv	seg_986976.csv	seg_c7b424.csv	seg_f99b64.csv
# seg_2f4f14.csv	seg_655ad6.csv	seg_986b6e.csv	seg_c80857.csv	seg_f9e4f2.csv
# seg_2f5695.csv	seg_655cae.csv	seg_9872f9.csv	seg_c81e10.csv	seg_f9eea3.csv
# seg_2f60db.csv	seg_658bf4.csv	seg_988e69.csv	seg_c81fec.csv	seg_fa0ac7.csv
# seg_2f86cd.csv	seg_659ff8.csv	seg_98a819.csv	seg_c8459f.csv	seg_fa34c7.csv
# seg_2f8e19.csv	seg_65b962.csv	seg_98be13.csv	seg_c87c24.csv	seg_fa488e.csv
# seg_2f8f6d.csv	seg_65c4e1.csv	seg_98c0b6.csv	seg_c901c0.csv	seg_fa4df0.csv
# seg_2f9336.csv	seg_65ef95.csv	seg_98c44d.csv	seg_c90be5.csv	seg_fa6383.csv
# seg_2f9581.csv	seg_65f01e.csv	seg_98c544.csv	seg_c9201c.csv	seg_fa796b.csv
# seg_2fb672.csv	seg_65fbac.csv	seg_98ebaa.csv	seg_c9481f.csv	seg_fa9f00.csv
# seg_2fe382.csv	seg_660fe1.csv	seg_98f624.csv	seg_c94941.csv	seg_fad815.csv
# seg_301c1e.csv	seg_660fef.csv	seg_9940e8.csv	seg_c9831a.csv	seg_fb00b3.csv
# seg_30207d.csv	seg_661629.csv	seg_996c37.csv	seg_c9e533.csv	seg_fb11ba.csv
# seg_304581.csv	seg_666056.csv	seg_99ccbd.csv	seg_c9f80a.csv	seg_fb1f5c.csv
# seg_304b87.csv	seg_6681ee.csv	seg_99f677.csv	seg_ca2d1b.csv	seg_fb4c26.csv
# seg_304df5.csv	seg_66820a.csv	seg_99f76c.csv	seg_ca407b.csv	seg_fb74f0.csv
# seg_30501b.csv	seg_6696d0.csv	seg_9a1a4f.csv	seg_ca44a8.csv	seg_fb76ca.csv
# seg_3065ba.csv	seg_66b7c3.csv	seg_9a1c76.csv	seg_ca67ee.csv	seg_fb8af5.csv
# seg_30661b.csv	seg_66e45a.csv	seg_9a43ef.csv	seg_ca6d70.csv	seg_fb9491.csv
# seg_306756.csv	seg_66ed4d.csv	seg_9a6025.csv	seg_ca8389.csv	seg_fb9b2e.csv
# seg_30ad2a.csv	seg_670bde.csv	seg_9a74d8.csv	seg_ca88e3.csv	seg_fbce13.csv
# seg_30b043.csv	seg_67330f.csv	seg_9a7c46.csv	seg_ca9e39.csv	seg_fbd66b.csv
# seg_30da11.csv	seg_673c60.csv	seg_9a7d1d.csv	seg_caa919.csv	seg_fbddb9.csv
# seg_30fd84.csv	seg_67599b.csv	seg_9a812d.csv	seg_cacd0a.csv	seg_fbe3c2.csv
# seg_310230.csv	seg_679dd2.csv	seg_9a81a3.csv	seg_cacd58.csv	seg_fbf17a.csv
# seg_31064b.csv	seg_67aa76.csv	seg_9a8a1f.csv	seg_cb0e21.csv	seg_fbff25.csv
# seg_311499.csv	seg_68102c.csv	seg_9a9041.csv	seg_cb806c.csv	seg_fc407c.csv
# seg_311b5e.csv	seg_683ddf.csv	seg_9a92db.csv	seg_cbcce9.csv	seg_fc57d4.csv
# seg_3128e6.csv	seg_686edc.csv	seg_9aa6e2.csv	seg_cbfb19.csv	seg_fc8fd6.csv
# seg_3151ff.csv	seg_687a5c.csv	seg_9ab405.csv	seg_cc096e.csv	seg_fcb7d0.csv
# seg_31631c.csv	seg_68a484.csv	seg_9ad261.csv	seg_cc2c46.csv	seg_fcca66.csv
# seg_316f86.csv	seg_68da94.csv	seg_9ad925.csv	seg_cc2e9b.csv	seg_fcd32e.csv
# seg_318135.csv	seg_691a72.csv	seg_9ae1a1.csv	seg_cc4199.csv	seg_fd19b8.csv
# seg_31a51f.csv	seg_692e7a.csv	seg_9b0439.csv	seg_cc4932.csv	seg_fd374e.csv
# seg_31a6cd.csv	seg_6951e0.csv	seg_9b44d2.csv	seg_cc4950.csv	seg_fd6340.csv
# seg_31b808.csv	seg_695380.csv	seg_9b7ef8.csv	seg_cc667b.csv	seg_fd8add.csv
# seg_31c0f4.csv	seg_696621.csv	seg_9b7f93.csv	seg_cc7a19.csv	seg_fd9ac1.csv
# seg_31d763.csv	seg_6968c8.csv	seg_9bab11.csv	seg_cc7e39.csv	seg_fdba93.csv
# seg_31d7bf.csv	seg_69787a.csv	seg_9bd388.csv	seg_ccdc28.csv	seg_fdc1d4.csv
# seg_31d810.csv	seg_69a230.csv	seg_9bee43.csv	seg_cd0691.csv	seg_fdd50e.csv
# seg_31ddc5.csv	seg_69a53e.csv	seg_9c00d7.csv	seg_cd2b34.csv	seg_fde767.csv
# seg_3234ca.csv	seg_69dbad.csv	seg_9c090f.csv	seg_cd2b53.csv	seg_fde86d.csv
# seg_324447.csv	seg_6a05e7.csv	seg_9c2843.csv	seg_cd352f.csv	seg_fdff11.csv
# seg_324537.csv	seg_6a116b.csv	seg_9c3d6a.csv	seg_cd43b4.csv	seg_fe2aac.csv
# seg_325790.csv	seg_6a26de.csv	seg_9c3ef8.csv	seg_cd699e.csv	seg_fe5945.csv
# seg_326eb7.csv	seg_6a45a0.csv	seg_9c635d.csv	seg_cd9f9b.csv	seg_fe70c0.csv
# seg_327ed4.csv	seg_6a4ad1.csv	seg_9c6715.csv	seg_cdadb5.csv	seg_fe73b1.csv
# seg_32906d.csv	seg_6ab188.csv	seg_9c8162.csv	seg_cdf88e.csv	seg_fe86f5.csv
# seg_32ad0f.csv	seg_6ac67a.csv	seg_9c8bc8.csv	seg_ce00bb.csv	seg_fea3e2.csv
# seg_32c904.csv	seg_6ac82a.csv	seg_9ca72e.csv	seg_ce46ba.csv	seg_feb312.csv
# seg_32d747.csv	seg_6ae32d.csv	seg_9caf50.csv	seg_ce472b.csv	seg_fedbd1.csv
# seg_32e763.csv	seg_6b0107.csv	seg_9cb464.csv	seg_ce5520.csv	seg_ff0f1b.csv
# seg_32f3a9.csv	seg_6b2ce0.csv	seg_9d1b26.csv	seg_ce5832.csv	seg_ff1a62.csv
# seg_32f6df.csv	seg_6b3a9d.csv	seg_9d1dbe.csv	seg_ce72e2.csv	seg_ff2f2d.csv
# seg_32f72d.csv	seg_6b4e04.csv	seg_9d2528.csv	seg_ce7537.csv	seg_ff4236.csv
# seg_32fc4e.csv	seg_6b536d.csv	seg_9d3013.csv	seg_ce9f59.csv	seg_ff7478.csv
# seg_330579.csv	seg_6b9511.csv	seg_9d452d.csv	seg_cea185.csv	seg_ff79d9.csv
# seg_3319b5.csv	seg_6b9d02.csv	seg_9d57a1.csv	seg_ceab44.csv	seg_ffbd6a.csv
# seg_331f2b.csv	seg_6be48e.csv	seg_9d68cf.csv	seg_ceb942.csv	seg_ffe7cc.csv
# seg_3340b9.csv	seg_6c292b.csv	seg_9d6ff0.csv	seg_cec2f2.csv

# %%
seg_df = pd.read_csv('../input/test/seg_00030f.csv', dtype={'acoustic_data': np.float32})

# %%
seg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 1 columns):
# acoustic_data    150000 non-null float32
# dtypes: float32(1)
# memory usage: 586.0 KB

# %%
seg_df.head()
# Out:
#    acoustic_data
# 0            4.0
# 1            0.0
# 2           -2.0
# 3            0.0
# 4            2.0

# %%
featured_seg_df = add_features(seg_df, holdout_size=0)
# Out:
# Full calculation feature value time (with slicing) 1.6346824367841084 min:

# %%
segment_names_ls = os.listdir('../input/test/')

# %%
total_add_features_minutes = len(segment_names_ls) * 1.64

# %%
total_add_features_minutes
# Out:
# 4303.36

# %%
min_in_day = 24 * 60

# %%
min_in_day
# Out:
# 1440

# %%
days = total_add_features_minutes / min_in_day

# %%
days
# Out:
# 2.9884444444444442
